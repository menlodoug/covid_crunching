# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#               date country_code  admin_level   admin1 admin2     fips  \
# 0       2020-03-01           US            1  Alabama    NaN     1.00
# 1       2020-03-02           US            1  Alabama    NaN     1.00
# 2       2020-03-03           US            1  Alabama    NaN     1.00
# 3       2020-03-04           US            1  Alabama    NaN     1.00
# 4       2020-03-05           US            1  Alabama    NaN     1.00
# ...            ...          ...          ...      ...    ...      ...
# 938568  2021-02-23           US            2  Wyoming  Uinta 56041.00
# 938569  2021-02-24           US            2  Wyoming  Uinta 56041.00
# 938570  2021-02-25           US            2  Wyoming  Uinta 56041.00
# 938571  2021-02-26           US            2  Wyoming  Uinta 56041.00
# 938572  2021-02-27           US            2  Wyoming  Uinta 56041.00
#
#         samples   m50  m50_index
# 0        133826  8.33         79
# 1        143632 10.40         98
# 2        146009 10.54        100
# 3        149352 10.14         96
# 4        144109 10.98        104
# ...         ...   ...        ...
# 938568      789  3.57        114
# 938569      805  3.60        115
# 938570      829  4.93        157
# 938571      758  3.35        107
# 938572      753  5.38        171
#
# [938573 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
