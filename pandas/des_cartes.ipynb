# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#               date country_code  admin_level   admin1 admin2     fips  \
# 0       2020-03-01           US            1  Alabama    NaN     1.00
# 1       2020-03-02           US            1  Alabama    NaN     1.00
# 2       2020-03-03           US            1  Alabama    NaN     1.00
# 3       2020-03-04           US            1  Alabama    NaN     1.00
# 4       2020-03-05           US            1  Alabama    NaN     1.00
# ...            ...          ...          ...      ...    ...      ...
# 897738  2021-02-08           US            2  Wyoming  Uinta 56041.00
# 897739  2021-02-09           US            2  Wyoming  Uinta 56041.00
# 897740  2021-02-10           US            2  Wyoming  Uinta 56041.00
# 897741  2021-02-11           US            2  Wyoming  Uinta 56041.00
# 897742  2021-02-12           US            2  Wyoming  Uinta 56041.00
#
#         samples   m50  m50_index
# 0        133826  8.33         79
# 1        143632 10.40         98
# 2        146009 10.54        100
# 3        149352 10.14         96
# 4        144109 10.98        104
# ...         ...   ...        ...
# 897738      660  2.99         95
# 897739      634  3.45        110
# 897740      640  3.63        115
# 897741      619  3.37        107
# 897742      603  3.21        102
#
# [897743 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
