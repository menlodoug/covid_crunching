# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#                date country_code  admin_level   admin1 admin2     fips  \
# 0        2020-03-01           US            1  Alabama    NaN     1.00
# 1        2020-03-02           US            1  Alabama    NaN     1.00
# 2        2020-03-03           US            1  Alabama    NaN     1.00
# 3        2020-03-04           US            1  Alabama    NaN     1.00
# 4        2020-03-05           US            1  Alabama    NaN     1.00
# ...             ...          ...          ...      ...    ...      ...
# 1052874  2021-04-06           US            2  Wyoming  Uinta 56041.00
# 1052875  2021-04-08           US            2  Wyoming  Uinta 56041.00
# 1052876  2021-04-09           US            2  Wyoming  Uinta 56041.00
# 1052877  2021-04-10           US            2  Wyoming  Uinta 56041.00
# 1052878  2021-04-11           US            2  Wyoming  Uinta 56041.00
#
#          samples   m50  m50_index
# 0         133826  8.33         79
# 1         143632 10.40         98
# 2         146009 10.54        100
# 3         149352 10.14         96
# 4         144109 10.98        104
# ...          ...   ...        ...
# 1052874      712  4.49        143
# 1052875      723  6.28        200
# 1052876      745  8.24        263
# 1052877      721  7.38        235
# 1052878      728  5.57        177
#
# [1052879 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
