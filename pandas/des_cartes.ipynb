# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#                date country_code  admin_level   admin1 admin2     fips  \
# 0        2020-03-01           US            1  Alabama    NaN     1.00
# 1        2020-03-02           US            1  Alabama    NaN     1.00
# 2        2020-03-03           US            1  Alabama    NaN     1.00
# 3        2020-03-04           US            1  Alabama    NaN     1.00
# 4        2020-03-05           US            1  Alabama    NaN     1.00
# ...             ...          ...          ...      ...    ...      ...
# 1020224  2021-03-25           US            2  Wyoming  Uinta 56041.00
# 1020225  2021-03-26           US            2  Wyoming  Uinta 56041.00
# 1020226  2021-03-27           US            2  Wyoming  Uinta 56041.00
# 1020227  2021-03-28           US            2  Wyoming  Uinta 56041.00
# 1020228  2021-03-29           US            2  Wyoming  Uinta 56041.00
#
#          samples   m50  m50_index
# 0         133826  8.33         79
# 1         143632 10.40         98
# 2         146009 10.54        100
# 3         149352 10.14         96
# 4         144109 10.98        104
# ...          ...   ...        ...
# 1020224      726  5.40        172
# 1020225      734  7.03        224
# 1020226      735  9.08        289
# 1020227      737  4.19        133
# 1020228      710  3.89        124
#
# [1020229 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
