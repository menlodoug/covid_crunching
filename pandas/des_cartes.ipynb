# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#                date country_code  admin_level   admin1 admin2     fips  \
# 0        2020-03-01           US            1  Alabama    NaN     1.00
# 1        2020-03-02           US            1  Alabama    NaN     1.00
# 2        2020-03-03           US            1  Alabama    NaN     1.00
# 3        2020-03-04           US            1  Alabama    NaN     1.00
# 4        2020-03-05           US            1  Alabama    NaN     1.00
# ...             ...          ...          ...      ...    ...      ...
# 1069174  2021-04-14           US            2  Wyoming  Uinta 56041.00
# 1069175  2021-04-15           US            2  Wyoming  Uinta 56041.00
# 1069176  2021-04-16           US            2  Wyoming  Uinta 56041.00
# 1069177  2021-04-17           US            2  Wyoming  Uinta 56041.00
# 1069178  2021-04-18           US            2  Wyoming  Uinta 56041.00
#
#          samples   m50  m50_index
# 0         133826  8.33         79
# 1         143632 10.40         98
# 2         146009 10.54        100
# 3         149352 10.14         96
# 4         144109 10.98        104
# ...          ...   ...        ...
# 1069174      729  3.72        118
# 1069175      733  4.02        128
# 1069176      727  5.02        160
# 1069177      748  6.73        214
# 1069178      766  3.44        109
#
# [1069179 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
