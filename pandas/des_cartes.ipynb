# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#                date country_code  admin_level   admin1 admin2     fips  \
# 0        2020-03-01           US            1  Alabama    NaN     1.00
# 1        2020-03-02           US            1  Alabama    NaN     1.00
# 2        2020-03-03           US            1  Alabama    NaN     1.00
# 3        2020-03-04           US            1  Alabama    NaN     1.00
# 4        2020-03-05           US            1  Alabama    NaN     1.00
# ...             ...          ...          ...      ...    ...      ...
# 1006615  2021-03-20           US            2  Wyoming  Uinta 56041.00
# 1006616  2021-03-21           US            2  Wyoming  Uinta 56041.00
# 1006617  2021-03-22           US            2  Wyoming  Uinta 56041.00
# 1006618  2021-03-23           US            2  Wyoming  Uinta 56041.00
# 1006619  2021-03-24           US            2  Wyoming  Uinta 56041.00
#
#          samples   m50  m50_index
# 0         133826  8.33         79
# 1         143632 10.40         98
# 2         146009 10.54        100
# 3         149352 10.14         96
# 4         144109 10.98        104
# ...          ...   ...        ...
# 1006615      718  4.22        134
# 1006616      758  3.90        124
# 1006617      775  4.70        149
# 1006618      744  3.81        121
# 1006619      784  6.56        209
#
# [1006620 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
