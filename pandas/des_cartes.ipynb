# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#               date country_code  admin_level   admin1 admin2     fips  \
# 0       2020-03-01           US            1  Alabama    NaN     1.00
# 1       2020-03-02           US            1  Alabama    NaN     1.00
# 2       2020-03-03           US            1  Alabama    NaN     1.00
# 3       2020-03-04           US            1  Alabama    NaN     1.00
# 4       2020-03-05           US            1  Alabama    NaN     1.00
# ...            ...          ...          ...      ...    ...      ...
# 911348  2021-02-13           US            2  Wyoming  Uinta 56041.00
# 911349  2021-02-14           US            2  Wyoming  Uinta 56041.00
# 911350  2021-02-15           US            2  Wyoming  Uinta 56041.00
# 911351  2021-02-16           US            2  Wyoming  Uinta 56041.00
# 911352  2021-02-17           US            2  Wyoming  Uinta 56041.00
#
#         samples   m50  m50_index
# 0        133826  8.33         79
# 1        143632 10.40         98
# 2        146009 10.54        100
# 3        149352 10.14         96
# 4        144109 10.98        104
# ...         ...   ...        ...
# 911348      601  2.47         78
# 911349      633  1.51         48
# 911350      633  2.46         78
# 911351      756  3.14        100
# 911352      780  3.72        118
#
# [911353 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
