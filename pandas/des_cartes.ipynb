# %%
import pandas as pd
import numpy as np
import re
pd.options.display.float_format = '{:.2f}'.format

# %%
des_cartes = pd.read_csv('https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv')
des_cartes['admin2'] = des_cartes['admin2'].str.replace(r' County$', '')
des_cartes
# Out:
#               date country_code  admin_level   admin1 admin2     fips  \
# 0       2020-03-01           US            1  Alabama    NaN     1.00
# 1       2020-03-02           US            1  Alabama    NaN     1.00
# 2       2020-03-03           US            1  Alabama    NaN     1.00
# 3       2020-03-04           US            1  Alabama    NaN     1.00
# 4       2020-03-05           US            1  Alabama    NaN     1.00
# ...            ...          ...          ...      ...    ...      ...
# 984842  2021-03-12           US            2  Wyoming  Uinta 56041.00
# 984843  2021-03-13           US            2  Wyoming  Uinta 56041.00
# 984844  2021-03-14           US            2  Wyoming  Uinta 56041.00
# 984845  2021-03-15           US            2  Wyoming  Uinta 56041.00
# 984846  2021-03-16           US            2  Wyoming  Uinta 56041.00
#
#         samples   m50  m50_index
# 0        133826  8.33         79
# 1        143632 10.40         98
# 2        146009 10.54        100
# 3        149352 10.14         96
# 4        144109 10.98        104
# ...         ...   ...        ...
# 984842      744  4.69        149
# 984843      695  2.55         81
# 984844      649  1.51         48
# 984845      649  2.52         80
# 984846      689  2.32         73
#
# [984847 rows x 9 columns]

# %%
des_cartes.to_csv('des_cartes.csv', index=False)
