# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.2f}'.format

# %%
sn = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-nursing-home-county-totals.csv')
sn['state'] = 'California'
sn['state2'] = 'CA'
sn.rename(columns = {'minimum_staff_confirmed_cases':'Staff Confirmed Cases', 'minimum_patients_confirmed_cases':'Patients Confirmed Cases', 
                              'minimum_staff_deaths':'Staff Deaths', 'minimum_patients_deaths':'Patients Deaths'}, inplace = True)
sn
# Out:
#              date        county  fips  Staff Confirmed Cases  \
# 0      2020-06-05       Alameda     1                    141
# 1      2020-06-05         Butte     7                      1
# 2      2020-06-05  Contra Costa    13                     38
# 3      2020-06-05     El Dorado    17                      1
# 4      2020-06-05        Fresno    19                     43
# ...           ...           ...   ...                    ...
# 31728  2022-01-15        Tulare   107                   1122
# 31729  2022-01-15      Tuolumne   109                     90
# 31730  2022-01-15       Ventura   111                   1141
# 31731  2022-01-15          Yolo   113                    306
# 31732  2022-01-15          Yuba   115                     73
#
#        Patients Confirmed Cases  Staff Deaths  Patients Deaths       state  \
# 0                           245             0               27  California
# 1                             1             0                0  California
# ...

# %%
sn.to_csv('nurse.csv', index=False)

# %%
sc = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-adult-and-senior-care-facilities.csv')
sc['state'] = 'California'
sc['state2'] = 'CA'
sc.head(5)
# Out:
#          date                              name   county  \
# 0  2021-06-27         Acacia Creek - Union City  Alameda
# 1  2021-06-27  Aegis Assisted Living Of Fremont  Alameda
# 2  2021-06-27    Arcadian Residential Community  Alameda
# 3  2021-06-27            Belmont Village Albany  Alameda
# 4  2021-06-27           Brookdale North Fremont  Alameda
#
#    staff_confirmed_cases  patients_confirmed_cases  staff_deaths  \
# 0                      1                         1          0.00
# 1                     12                        15          0.00
# 2                     15                        28          0.00
# 3                     15                         1          0.00
# 4                     22                        26          0.00
#
#    patients_deaths  fips staff_confirmed_cases_note  \
# 0             0.00     1                        <11
# 1             0.00     1                        NaN
# 2             1.00     1                        NaN
# ...

# %%
sc.to_csv('SC.csv')
