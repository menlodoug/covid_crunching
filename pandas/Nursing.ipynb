# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.2f}'.format

# %%
sn = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-nursing-home-county-totals.csv')
sn['state'] = 'California'
sn['state2'] = 'CA'
sn.rename(columns = {'minimum_staff_confirmed_cases':'Staff Confirmed Cases', 'minimum_patients_confirmed_cases':'Patients Confirmed Cases', 
                              'minimum_staff_deaths':'Staff Deaths', 'minimum_patients_deaths':'Patients Deaths'}, inplace = True)
sn
# Out:
#              date        county  fips  Staff Confirmed Cases  \
# 0      2020-06-05       Alameda     1                    143
# 1      2020-06-05         Butte     7                      1
# 2      2020-06-05  Contra Costa    13                     71
# 3      2020-06-05     El Dorado    17                      1
# 4      2020-06-05        Fresno    19                     43
# ...           ...           ...   ...                    ...
# 22544  2021-08-04        Tulare   107                    884
# 22545  2021-08-04      Tuolumne   109                     66
# 22546  2021-08-04       Ventura   111                   1371
# 22547  2021-08-04          Yolo   113                    317
# 22548  2021-08-04          Yuba   115                     46
#
#        Patients Confirmed Cases  Staff Deaths  Patients Deaths       state  \
# 0                           258             0               28  California
# 1                             1             0                0  California
# 2                           105             3                5  California
# 3                             0             0                0  California
# 4                           118             2               27  California
# ...                         ...           ...              ...         ...
# 22544                      1015             1              151  California
# 22545                       122             0               15  California
# 22546                      1580             1              127  California
# 22547                       309             2               41  California
# 22548                        85             0                2  California
#
#       state2
# 0         CA
# 1         CA
# 2         CA
# 3         CA
# 4         CA
# ...      ...
# 22544     CA
# 22545     CA
# 22546     CA
# 22547     CA
# 22548     CA
#
# [22549 rows x 9 columns]

# %%
sn.to_csv('nurse.csv', index=False)

# %%
sc = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-adult-and-senior-care-facilities.csv')
sc['state'] = 'California'
sc['state2'] = 'CA'
sc.head(5)
# Out:
#          date                              slug  \
# 0  2021-06-27           acacia-creek-union-city
# 1  2021-06-27  aegis-assisted-living-of-fremont
# 2  2021-06-27    arcadian-residential-community
# 3  2021-06-27            belmont-village-albany
# 4  2021-06-27           brookdale-north-fremont
#
#                                name   county  staff_confirmed_cases  \
# 0         ACACIA CREEK - UNION CITY  Alameda                      1
# 1  AEGIS ASSISTED LIVING OF FREMONT  Alameda                     12
# 2    ARCADIAN RESIDENTIAL COMMUNITY  Alameda                     15
# 3            BELMONT VILLAGE ALBANY  Alameda                     15
# 4           BROOKDALE NORTH FREMONT  Alameda                     22
#
#    patients_confirmed_cases  staff_deaths  patients_deaths  fips  \
# 0                         1          0.00             0.00     1
# 1                        15          0.00             0.00     1
# 2                        28          0.00             1.00     1
# 3                         1          0.00             0.00     1
# 4                        26          0.00             1.00     1
#
#   staff_confirmed_cases_note patients_confirmed_cases_note staff_deaths_note  \
# 0                        <11                           <11               NaN
# 1                        NaN                           NaN               NaN
# 2                        NaN                           NaN               NaN
# 3                        NaN                           <11               NaN
# 4                        NaN                           NaN               NaN
#
#   patients_deaths_note       state state2
# 0                  NaN  California     CA
# 1                  NaN  California     CA
# 2                  <11  California     CA
# 3                  NaN  California     CA
# 4                  <11  California     CA

# %%
sc.to_csv('SC.csv')
