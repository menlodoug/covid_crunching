# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.2f}'.format

# %%
sn = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-nursing-home-county-totals.csv')
sn['state'] = 'California'
sn['state2'] = 'CA'
sn.rename(columns = {'minimum_staff_confirmed_cases':'Staff Confirmed Cases', 'minimum_patients_confirmed_cases':'Patients Confirmed Cases', 
                              'minimum_staff_deaths':'Staff Deaths', 'minimum_patients_deaths':'Patients Deaths'}, inplace = True)
sn
# Out:
#              date        county  fips  Staff Confirmed Cases  \
# 0      2020-06-05       Alameda     1                    143
# 1      2020-06-05         Butte     7                      1
# 2      2020-06-05  Contra Costa    13                     71
# 3      2020-06-05     El Dorado    17                      1
# 4      2020-06-05        Fresno    19                     43
# ...           ...           ...   ...                    ...
# 13640  2021-02-26        Tulare   107                    863
# 13641  2021-02-26      Tuolumne   109                     57
# 13642  2021-02-26       Ventura   111                   1358
# 13643  2021-02-26          Yolo   113                    293
# 13644  2021-02-26          Yuba   115                     41
#
#        Patients Confirmed Cases  Staff Deaths  Patients Deaths       state  \
# 0                           258             0               28  California
# 1                             1             0                0  California
# 2                           105             3                5  California
# 3                             0             0                0  California
# 4                           118             2               27  California
# ...                         ...           ...              ...         ...
# 13640                      1001             1              147  California
# 13641                       119             0               15  California
# 13642                      1555             1              122  California
# 13643                       301             2               41  California
# 13644                        82             0                2  California
#
#       state2
# 0         CA
# 1         CA
# 2         CA
# 3         CA
# 4         CA
# ...      ...
# 13640     CA
# 13641     CA
# 13642     CA
# 13643     CA
# 13644     CA
#
# [13645 rows x 9 columns]

# %%
sn.to_csv('nurse.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-0b3385ce1475> in <module>
# ----> 1 sn.to_csv('nurse.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'nurse.csv'

# %%
sc = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-adult-and-senior-care-facilities.csv')
sc['state'] = 'California'
sc['state2'] = 'CA'
sc.head(5)

# %%
sc.to_csv('SC.csv')
