# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 7586011                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7586012                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7586013                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7586014                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7586015                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 7586011        NaN             NaN                 0
# 7586012        NaN             NaN                 0
# 7586013        NaN             NaN                 0
# 7586014        NaN             NaN                 0
# 7586015        NaN             NaN                 0
#
#                             place_id        date  \
# 7586011  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-11-02
# 7586012  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-11-03
# 7586013  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-11-04
# 7586014  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-11-05
# 7586015  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-11-08
#
#          retail_and_recreation_percent_change_from_baseline  \
# 7586011                                                nan
# 7586012                                                nan
# 7586013                                                nan
# 7586014                                                nan
# 7586015                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 7586011                                                nan
# 7586012                                                nan
# 7586013                                                nan
# 7586014                                                nan
# 7586015                                                nan
#
#          parks_percent_change_from_baseline  \
# 7586011                                 nan
# 7586012                                 nan
# 7586013                                 nan
# 7586014                                 nan
# 7586015                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 7586011                                            nan
# 7586012                                            nan
# 7586013                                            nan
# 7586014                                            nan
# 7586015                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 7586011                                    49.00
# 7586012                                    44.00
# 7586013                                    38.00
# 7586014                                    46.00
# 7586015                                    34.00
#
#          residential_percent_change_from_baseline
# 7586011                                       nan
# 7586012                                       nan
# 7586013                                       nan
# 7586014                                       nan
# 7586015                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google
# Out:
# <ipython-input-3-ef2a8e8188a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
#         country_region_code country_region sub_region_1 sub_region_2  \
# 5887886                  US  United States          NaN          NaN
# 5887887                  US  United States          NaN          NaN
# 5887888                  US  United States          NaN          NaN
# 5887889                  US  United States          NaN          NaN
# 5887890                  US  United States          NaN          NaN
# ...                     ...            ...          ...          ...
# 7512983                  US  United States      Wyoming       Weston
# 7512984                  US  United States      Wyoming       Weston
# 7512985                  US  United States      Wyoming       Weston
# 7512986                  US  United States      Wyoming       Weston
# 7512987                  US  United States      Wyoming       Weston
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 5887886        NaN             NaN                 0
# 5887887        NaN             NaN                 0
# 5887888        NaN             NaN                 0
# 5887889        NaN             NaN                 0
# 5887890        NaN             NaN                 0
# ...            ...             ...               ...
# 7512983        NaN             NaN             56045
# 7512984        NaN             NaN             56045
# 7512985        NaN             NaN             56045
# 7512986        NaN             NaN             56045
# 7512987        NaN             NaN             56045
#
#                             place_id        date  \
# 5887886  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 5887887  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 5887888  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 5887889  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 5887890  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                              ...         ...
# 7512983  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-11-02
# 7512984  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-11-03
# 7512985  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-11-04
# 7512986  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-11-05
# 7512987  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-11-08
#
#          retail_and_recreation_percent_change_from_baseline  \
# 5887886                                               6.00
# 5887887                                               7.00
# 5887888                                               6.00
# 5887889                                               0.00
# 5887890                                               2.00
# ...                                                    ...
# 7512983                                                nan
# 7512984                                                nan
# 7512985                                                nan
# 7512986                                                nan
# 7512987                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 5887886                                               2.00
# 5887887                                               1.00
# 5887888                                               0.00
# 5887889                                              -1.00
# 5887890                                               0.00
# ...                                                    ...
# 7512983                                                nan
# 7512984                                                nan
# 7512985                                                nan
# 7512986                                                nan
# 7512987                                                nan
#
#          parks_percent_change_from_baseline  \
# 5887886                               15.00
# 5887887                               16.00
# 5887888                               28.00
# 5887889                                6.00
# 5887890                                8.00
# ...                                     ...
# 7512983                                 nan
# 7512984                                 nan
# 7512985                                 nan
# 7512986                                 nan
# 7512987                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 5887886                                           3.00
# 5887887                                           2.00
# 5887888                                          -9.00
# 5887889                                           1.00
# 5887890                                           1.00
# ...                                                ...
# 7512983                                            nan
# 7512984                                            nan
# 7512985                                            nan
# 7512986                                            nan
# 7512987                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 5887886                                     2.00
# 5887887                                     0.00
# 5887888                                   -24.00
# 5887889                                     0.00
# 5887890                                     1.00
# ...                                          ...
# 7512983                                   -20.00
# 7512984                                   -26.00
# 7512985                                   -24.00
# 7512986                                   -24.00
# 7512987                                   -29.00
#
#          residential_percent_change_from_baseline
# 5887886                                     -1.00
# 5887887                                     -1.00
# 5887888                                      5.00
# 5887889                                      1.00
# 5887890                                      0.00
# ...                                           ...
# 7512983                                       nan
# 7512984                                       nan
# 7512985                                       nan
# 7512986                                       nan
# 7512987                                       nan
#
# [1625102 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
