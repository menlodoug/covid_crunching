# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 7155461                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7155462                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7155463                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7155464                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 7155465                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 7155461        NaN             NaN                 0
# 7155462        NaN             NaN                 0
# 7155463        NaN             NaN                 0
# 7155464        NaN             NaN                 0
# 7155465        NaN             NaN                 0
#
#                             place_id        date  \
# 7155461  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-09-28
# 7155462  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-09-29
# 7155463  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-09-30
# 7155464  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-10-01
# 7155465  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-10-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 7155461                                                nan
# 7155462                                                nan
# 7155463                                                nan
# 7155464                                                nan
# 7155465                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 7155461                                                nan
# 7155462                                                nan
# 7155463                                                nan
# 7155464                                                nan
# 7155465                                                nan
#
#          parks_percent_change_from_baseline  \
# 7155461                                 nan
# 7155462                                 nan
# 7155463                                 nan
# 7155464                                 nan
# 7155465                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 7155461                                            nan
# 7155462                                            nan
# 7155463                                            nan
# 7155464                                            nan
# 7155465                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 7155461                                    36.00
# 7155462                                    41.00
# 7155463                                    36.00
# 7155464                                    38.00
# 7155465                                    30.00
#
#          residential_percent_change_from_baseline
# 7155461                                       nan
# 7155462                                       nan
# 7155463                                       nan
# 7155464                                       nan
# 7155465                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google
# Out:
# <ipython-input-3-ef2a8e8188a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
#         country_region_code country_region sub_region_1 sub_region_2  \
# 5551285                  US  United States          NaN          NaN
# 5551286                  US  United States          NaN          NaN
# 5551287                  US  United States          NaN          NaN
# 5551288                  US  United States          NaN          NaN
# 5551289                  US  United States          NaN          NaN
# ...                     ...            ...          ...          ...
# 7085330                  US  United States      Wyoming       Weston
# 7085331                  US  United States      Wyoming       Weston
# 7085332                  US  United States      Wyoming       Weston
# 7085333                  US  United States      Wyoming       Weston
# 7085334                  US  United States      Wyoming       Weston
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 5551285        NaN             NaN                 0
# 5551286        NaN             NaN                 0
# 5551287        NaN             NaN                 0
# 5551288        NaN             NaN                 0
# 5551289        NaN             NaN                 0
# ...            ...             ...               ...
# 7085330        NaN             NaN             56045
# 7085331        NaN             NaN             56045
# 7085332        NaN             NaN             56045
# 7085333        NaN             NaN             56045
# 7085334        NaN             NaN             56045
#
#                             place_id        date  \
# 5551285  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 5551286  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 5551287  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 5551288  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 5551289  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                              ...         ...
# 7085330  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-09-28
# 7085331  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-09-29
# 7085332  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-09-30
# 7085333  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-10-01
# 7085334  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-10-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 5551285                                               6.00
# 5551286                                               7.00
# 5551287                                               6.00
# 5551288                                               0.00
# 5551289                                               2.00
# ...                                                    ...
# 7085330                                                nan
# 7085331                                                nan
# 7085332                                                nan
# 7085333                                                nan
# 7085334                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 5551285                                               2.00
# 5551286                                               1.00
# 5551287                                               0.00
# 5551288                                              -1.00
# 5551289                                               0.00
# ...                                                    ...
# 7085330                                                nan
# 7085331                                                nan
# 7085332                                                nan
# 7085333                                                nan
# 7085334                                                nan
#
#          parks_percent_change_from_baseline  \
# 5551285                               15.00
# 5551286                               16.00
# 5551287                               28.00
# 5551288                                6.00
# 5551289                                8.00
# ...                                     ...
# 7085330                                 nan
# 7085331                                 nan
# 7085332                                 nan
# 7085333                                 nan
# 7085334                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 5551285                                           3.00
# 5551286                                           2.00
# 5551287                                          -9.00
# 5551288                                           1.00
# 5551289                                           1.00
# ...                                                ...
# 7085330                                            nan
# 7085331                                            nan
# 7085332                                            nan
# 7085333                                            nan
# 7085334                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 5551285                                     2.00
# 5551286                                     0.00
# 5551287                                   -24.00
# 5551288                                     0.00
# 5551289                                     1.00
# ...                                          ...
# 7085330                                   -28.00
# 7085331                                   -21.00
# 7085332                                   -18.00
# 7085333                                   -21.00
# 7085334                                   -21.00
#
#          residential_percent_change_from_baseline
# 5551285                                     -1.00
# 5551286                                     -1.00
# 5551287                                      5.00
# 5551288                                      1.00
# 5551289                                      0.00
# ...                                           ...
# 7085330                                       nan
# 7085331                                       nan
# 7085332                                       nan
# 7085333                                       nan
# 7085334                                       nan
#
# [1534050 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
