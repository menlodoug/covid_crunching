# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 9540204                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 9540205                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 9540206                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 9540207                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 9540208                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 9540204        NaN             NaN                 0
# 9540205        NaN             NaN                 0
# 9540206        NaN             NaN                 0
# 9540207        NaN             NaN                 0
# 9540208        NaN             NaN                 0
#
#                             place_id        date  \
# 9540204  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-04-11
# 9540205  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-04-12
# 9540206  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-04-13
# 9540207  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-04-14
# 9540208  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-04-15
#
#          retail_and_recreation_percent_change_from_baseline  \
# 9540204                                                nan
# 9540205                                                nan
# 9540206                                                nan
# 9540207                                                nan
# 9540208                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 9540204                                                nan
# 9540205                                                nan
# 9540206                                                nan
# 9540207                                                nan
# 9540208                                                nan
#
#          parks_percent_change_from_baseline  \
# 9540204                                 nan
# 9540205                                 nan
# 9540206                                 nan
# 9540207                                 nan
# 9540208                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 9540204                                            nan
# 9540205                                            nan
# 9540206                                            nan
# 9540207                                            nan
# 9540208                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 9540204                                    88.00
# 9540205                                   107.00
# 9540206                                    95.00
# 9540207                                    87.00
# 9540208                                    25.00
#
#          residential_percent_change_from_baseline
# 9540204                                       nan
# 9540205                                       nan
# 9540206                                       nan
# 9540207                                       nan
# 9540208                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google
# Out:
# <ipython-input-3-ef2a8e8188a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
#         country_region_code country_region sub_region_1 sub_region_2  \
# 7408013                  US  United States          NaN          NaN
# 7408014                  US  United States          NaN          NaN
# 7408015                  US  United States          NaN          NaN
# 7408016                  US  United States          NaN          NaN
# 7408017                  US  United States          NaN          NaN
# ...                     ...            ...          ...          ...
# 9447400                  US  United States      Wyoming       Weston
# 9447401                  US  United States      Wyoming       Weston
# 9447402                  US  United States      Wyoming       Weston
# 9447403                  US  United States      Wyoming       Weston
# 9447404                  US  United States      Wyoming       Weston
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 7408013        NaN             NaN                 0
# 7408014        NaN             NaN                 0
# 7408015        NaN             NaN                 0
# 7408016        NaN             NaN                 0
# 7408017        NaN             NaN                 0
# ...            ...             ...               ...
# 9447400        NaN             NaN             56045
# 9447401        NaN             NaN             56045
# 9447402        NaN             NaN             56045
# 9447403        NaN             NaN             56045
# 9447404        NaN             NaN             56045
#
#                             place_id        date  \
# 7408013  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 7408014  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 7408015  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 7408016  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 7408017  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                              ...         ...
# 9447400  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-04-11
# 9447401  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-04-12
# 9447402  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-04-13
# 9447403  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-04-14
# 9447404  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-04-15
#
#          retail_and_recreation_percent_change_from_baseline  \
# 7408013                                               6.00
# 7408014                                               7.00
# 7408015                                               6.00
# 7408016                                               0.00
# 7408017                                               2.00
# ...                                                    ...
# 9447400                                                nan
# 9447401                                                nan
# 9447402                                                nan
# 9447403                                                nan
# 9447404                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 7408013                                               2.00
# 7408014                                               1.00
# 7408015                                               0.00
# 7408016                                              -1.00
# 7408017                                               0.00
# ...                                                    ...
# 9447400                                                nan
# 9447401                                                nan
# 9447402                                                nan
# 9447403                                                nan
# 9447404                                                nan
#
#          parks_percent_change_from_baseline  \
# 7408013                               15.00
# 7408014                               16.00
# 7408015                               28.00
# 7408016                                6.00
# 7408017                                8.00
# ...                                     ...
# 9447400                                 nan
# 9447401                                 nan
# 9447402                                 nan
# 9447403                                 nan
# 9447404                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 7408013                                           3.00
# 7408014                                           2.00
# 7408015                                          -9.00
# 7408016                                           1.00
# 7408017                                           1.00
# ...                                                ...
# 9447400                                            nan
# 9447401                                            nan
# 9447402                                            nan
# 9447403                                            nan
# 9447404                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 7408013                                     2.00
# 7408014                                     0.00
# 7408015                                   -24.00
# 7408016                                     0.00
# 7408017                                     1.00
# ...                                          ...
# 9447400                                   -22.00
# 9447401                                   -20.00
# 9447402                                   -23.00
# 9447403                                   -23.00
# 9447404                                   -39.00
#
#          residential_percent_change_from_baseline
# 7408013                                     -1.00
# 7408014                                     -1.00
# 7408015                                      5.00
# 7408016                                      1.00
# 7408017                                      0.00
# ...                                           ...
# 9447400                                       nan
# 9447401                                       nan
# 9447402                                       nan
# 9447403                                       nan
# 9447404                                       nan
#
# [2039392 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
