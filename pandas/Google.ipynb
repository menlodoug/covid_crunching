# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#          country_region_code country_region       sub_region_1 sub_region_2  \
# 10191720                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 10191721                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 10191722                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 10191723                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 10191724                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#          metro_area iso_3166_2_code  census_fips_code  \
# 10191720        NaN             NaN                 0
# 10191721        NaN             NaN                 0
# 10191722        NaN             NaN                 0
# 10191723        NaN             NaN                 0
# 10191724        NaN             NaN                 0
#
#                              place_id        date  \
# 10191720  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-06-03
# 10191721  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-06-06
# 10191722  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-06-07
# 10191723  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-06-08
# 10191724  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-06-09
#
#           retail_and_recreation_percent_change_from_baseline  \
# 10191720                                                nan
# 10191721                                                nan
# 10191722                                                nan
# 10191723                                                nan
# 10191724                                                nan
#
#           grocery_and_pharmacy_percent_change_from_baseline  \
# 10191720                                                nan
# 10191721                                                nan
# 10191722                                                nan
# 10191723                                                nan
# 10191724                                                nan
#
#           parks_percent_change_from_baseline  \
# 10191720                                 nan
# 10191721                                 nan
# 10191722                                 nan
# 10191723                                 nan
# 10191724                                 nan
#
#           transit_stations_percent_change_from_baseline  \
# 10191720                                            nan
# 10191721                                            nan
# 10191722                                            nan
# 10191723                                            nan
# 10191724                                            nan
#
#           workplaces_percent_change_from_baseline  \
# 10191720                                   130.00
# 10191721                                   113.00
# 10191722                                   145.00
# 10191723                                   139.00
# 10191724                                   123.00
#
#           residential_percent_change_from_baseline
# 10191720                                       nan
# 10191721                                       nan
# 10191722                                       nan
# 10191723                                       nan
# 10191724                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google["sub_region_2"] = us_google["sub_region_2"].fillna('Statewide')
us_google
# Out:
# <ipython-input-3-85bba7a4b043>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
# <ipython-input-3-85bba7a4b043>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"] = us_google["sub_region_2"].fillna('Statewide')
#          country_region_code country_region sub_region_1 sub_region_2  \
# 7912979                   US  United States          NaN    Statewide
# 7912980                   US  United States          NaN    Statewide
# 7912981                   US  United States          NaN    Statewide
# 7912982                   US  United States          NaN    Statewide
# 7912983                   US  United States          NaN    Statewide
# ...                      ...            ...          ...          ...
# 10092717                  US  United States      Wyoming       Weston
# 10092718                  US  United States      Wyoming       Weston
# 10092719                  US  United States      Wyoming       Weston
# 10092720                  US  United States      Wyoming       Weston
# 10092721                  US  United States      Wyoming       Weston
#
#          metro_area iso_3166_2_code  census_fips_code  \
# 7912979         NaN             NaN                 0
# 7912980         NaN             NaN                 0
# 7912981         NaN             NaN                 0
# 7912982         NaN             NaN                 0
# 7912983         NaN             NaN                 0
# ...             ...             ...               ...
# 10092717        NaN             NaN             56045
# 10092718        NaN             NaN             56045
# 10092719        NaN             NaN             56045
# 10092720        NaN             NaN             56045
# 10092721        NaN             NaN             56045
#
#                              place_id        date  \
# 7912979   ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 7912980   ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 7912981   ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 7912982   ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 7912983   ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                               ...         ...
# 10092717  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-06-03
# 10092718  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-06-06
# 10092719  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-06-07
# 10092720  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-06-08
# 10092721  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-06-09
#
#           retail_and_recreation_percent_change_from_baseline  \
# 7912979                                                6.00
# 7912980                                                7.00
# 7912981                                                6.00
# 7912982                                                0.00
# 7912983                                                2.00
# ...                                                     ...
# 10092717                                                nan
# 10092718                                                nan
# 10092719                                                nan
# 10092720                                                nan
# 10092721                                                nan
#
#           grocery_and_pharmacy_percent_change_from_baseline  \
# 7912979                                                2.00
# 7912980                                                1.00
# 7912981                                                0.00
# 7912982                                               -1.00
# 7912983                                                0.00
# ...                                                     ...
# 10092717                                                nan
# 10092718                                                nan
# 10092719                                                nan
# 10092720                                                nan
# 10092721                                                nan
#
#           parks_percent_change_from_baseline  \
# 7912979                                15.00
# 7912980                                16.00
# 7912981                                28.00
# 7912982                                 6.00
# 7912983                                 8.00
# ...                                      ...
# 10092717                                 nan
# 10092718                                 nan
# 10092719                                 nan
# 10092720                                 nan
# 10092721                                 nan
#
#           transit_stations_percent_change_from_baseline  \
# 7912979                                            3.00
# 7912980                                            2.00
# 7912981                                           -9.00
# 7912982                                            1.00
# 7912983                                            1.00
# ...                                                 ...
# 10092717                                            nan
# 10092718                                            nan
# 10092719                                            nan
# 10092720                                            nan
# 10092721                                            nan
#
#           workplaces_percent_change_from_baseline  \
# 7912979                                      2.00
# 7912980                                      0.00
# 7912981                                    -24.00
# 7912982                                      0.00
# 7912983                                      1.00
# ...                                           ...
# 10092717                                   -34.00
# 10092718                                   -39.00
# 10092719                                   -30.00
# 10092720                                   -36.00
# 10092721                                   -36.00
#
#           residential_percent_change_from_baseline
# 7912979                                      -1.00
# 7912980                                      -1.00
# 7912981                                       5.00
# 7912982                                       1.00
# 7912983                                       0.00
# ...                                            ...
# 10092717                                       nan
# 10092718                                       nan
# 10092719                                       nan
# 10092720                                       nan
# 10092721                                       nan
#
# [2179743 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
