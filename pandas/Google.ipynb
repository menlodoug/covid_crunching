# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#          country_region_code country_region       sub_region_1 sub_region_2  \
# 11371007                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11371008                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11371009                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11371010                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11371011                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#          metro_area iso_3166_2_code  census_fips_code  \
# 11371007        NaN             NaN                 0
# 11371008        NaN             NaN                 0
# 11371009        NaN             NaN                 0
# 11371010        NaN             NaN                 0
# 11371011        NaN             NaN                 0
#
#                              place_id        date  \
# 11371007  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-09-01
# 11371008  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-09-05
# ...

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google["sub_region_2"] = us_google["sub_region_2"].fillna('Statewide')
us_google
# Out:
# <ipython-input-3-85bba7a4b043>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
# <ipython-input-3-85bba7a4b043>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"] = us_google["sub_region_2"].fillna('Statewide')
#          country_region_code country_region sub_region_1 sub_region_2  \
# 8826239                   US  United States          NaN    Statewide
# ...

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
