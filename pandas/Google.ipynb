# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 6364636                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 6364637                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 6364638                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 6364639                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 6364640                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 6364636        NaN             NaN                 0
# 6364637        NaN             NaN                 0
# 6364638        NaN             NaN                 0
# 6364639        NaN             NaN                 0
# 6364640        NaN             NaN                 0
#
#                             place_id        date  \
# 6364636  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-07-26
# 6364637  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-07-27
# 6364638  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-07-28
# 6364639  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-07-29
# 6364640  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-07-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 6364636                                                nan
# 6364637                                                nan
# 6364638                                                nan
# 6364639                                                nan
# 6364640                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 6364636                                                nan
# 6364637                                                nan
# 6364638                                                nan
# 6364639                                                nan
# 6364640                                                nan
#
#          parks_percent_change_from_baseline  \
# 6364636                                 nan
# 6364637                                 nan
# 6364638                                 nan
# 6364639                                 nan
# 6364640                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 6364636                                            nan
# 6364637                                            nan
# 6364638                                            nan
# 6364639                                            nan
# 6364640                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 6364636                                    -5.00
# 6364637                                     6.00
# 6364638                                    18.00
# 6364639                                     1.00
# 6364640                                    12.00
#
#          residential_percent_change_from_baseline
# 6364636                                       nan
# 6364637                                       nan
# 6364638                                       nan
# 6364639                                       nan
# 6364640                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google
# Out:
# <ipython-input-3-ef2a8e8188a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
#         country_region_code country_region sub_region_1 sub_region_2  \
# 4934989                  US  United States          NaN          NaN
# 4934990                  US  United States          NaN          NaN
# 4934991                  US  United States          NaN          NaN
# 4934992                  US  United States          NaN          NaN
# 4934993                  US  United States          NaN          NaN
# ...                     ...            ...          ...          ...
# 6302064                  US  United States      Wyoming       Weston
# 6302065                  US  United States      Wyoming       Weston
# 6302066                  US  United States      Wyoming       Weston
# 6302067                  US  United States      Wyoming       Weston
# 6302068                  US  United States      Wyoming       Weston
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 4934989        NaN             NaN                 0
# 4934990        NaN             NaN                 0
# 4934991        NaN             NaN                 0
# 4934992        NaN             NaN                 0
# 4934993        NaN             NaN                 0
# ...            ...             ...               ...
# 6302064        NaN             NaN             56045
# 6302065        NaN             NaN             56045
# 6302066        NaN             NaN             56045
# 6302067        NaN             NaN             56045
# 6302068        NaN             NaN             56045
#
#                             place_id        date  \
# 4934989  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 4934990  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 4934991  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 4934992  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 4934993  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                              ...         ...
# 6302064  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-07-26
# 6302065  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-07-27
# 6302066  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-07-28
# 6302067  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-07-29
# 6302068  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-07-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 4934989                                               6.00
# 4934990                                               7.00
# 4934991                                               6.00
# 4934992                                               0.00
# 4934993                                               2.00
# ...                                                    ...
# 6302064                                                nan
# 6302065                                                nan
# 6302066                                                nan
# 6302067                                                nan
# 6302068                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 4934989                                               2.00
# 4934990                                               1.00
# 4934991                                               0.00
# 4934992                                              -1.00
# 4934993                                               0.00
# ...                                                    ...
# 6302064                                                nan
# 6302065                                                nan
# 6302066                                                nan
# 6302067                                                nan
# 6302068                                                nan
#
#          parks_percent_change_from_baseline  \
# 4934989                               15.00
# 4934990                               16.00
# 4934991                               28.00
# 4934992                                6.00
# 4934993                                8.00
# ...                                     ...
# 6302064                                 nan
# 6302065                                 nan
# 6302066                                 nan
# 6302067                                 nan
# 6302068                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 4934989                                           3.00
# 4934990                                           2.00
# 4934991                                          -9.00
# 4934992                                           1.00
# 4934993                                           1.00
# ...                                                ...
# 6302064                                            nan
# 6302065                                            nan
# 6302066                                            nan
# 6302067                                            nan
# 6302068                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 4934989                                     2.00
# 4934990                                     0.00
# 4934991                                   -24.00
# 4934992                                     0.00
# 4934993                                     1.00
# ...                                          ...
# 6302064                                   -35.00
# 6302065                                   -36.00
# 6302066                                   -38.00
# 6302067                                   -33.00
# 6302068                                   -37.00
#
#          residential_percent_change_from_baseline
# 4934989                                     -1.00
# 4934990                                     -1.00
# 4934991                                      5.00
# 4934992                                      1.00
# 4934993                                      0.00
# ...                                           ...
# 6302064                                       nan
# 6302065                                       nan
# 6302066                                       nan
# 6302067                                       nan
# 6302068                                       nan
#
# [1367080 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
