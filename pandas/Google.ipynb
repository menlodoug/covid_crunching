# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 4926007                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4926008                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4926009                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4926010                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4926011                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 4926007        NaN             NaN                 0
# 4926008        NaN             NaN                 0
# 4926009        NaN             NaN                 0
# 4926010        NaN             NaN                 0
# 4926011        NaN             NaN                 0
#
#                             place_id        date  \
# 4926007  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-01
# 4926008  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-02
# 4926009  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-05
# 4926010  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-06
# 4926011  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-07
#
#          retail_and_recreation_percent_change_from_baseline  \
# 4926007                                                nan
# 4926008                                                nan
# 4926009                                                nan
# 4926010                                                nan
# 4926011                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 4926007                                                nan
# 4926008                                                nan
# 4926009                                                nan
# 4926010                                                nan
# 4926011                                                nan
#
#          parks_percent_change_from_baseline  \
# 4926007                                 nan
# 4926008                                 nan
# 4926009                                 nan
# 4926010                                 nan
# 4926011                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 4926007                                            nan
# 4926008                                            nan
# 4926009                                            nan
# 4926010                                            nan
# 4926011                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 4926007                                     0.00
# 4926008                                   -33.00
# 4926009                                   -54.00
# 4926010                                    10.00
# 4926011                                     5.00
#
#          residential_percent_change_from_baseline
# 4926007                                       nan
# 4926008                                       nan
# 4926009                                       nan
# 4926010                                       nan
# 4926011                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google
# Out:
# <ipython-input-3-ef2a8e8188a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
#         country_region_code country_region sub_region_1 sub_region_2  \
# 3812100                  US  United States          NaN          NaN
# 3812101                  US  United States          NaN          NaN
# 3812102                  US  United States          NaN          NaN
# 3812103                  US  United States          NaN          NaN
# 3812104                  US  United States          NaN          NaN
# ...                     ...            ...          ...          ...
# 4877170                  US  United States      Wyoming       Weston
# 4877171                  US  United States      Wyoming       Weston
# 4877172                  US  United States      Wyoming       Weston
# 4877173                  US  United States      Wyoming       Weston
# 4877174                  US  United States      Wyoming       Weston
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 3812100        NaN             NaN                 0
# 3812101        NaN             NaN                 0
# 3812102        NaN             NaN                 0
# 3812103        NaN             NaN                 0
# 3812104        NaN             NaN                 0
# ...            ...             ...               ...
# 4877170        NaN             NaN             56045
# 4877171        NaN             NaN             56045
# 4877172        NaN             NaN             56045
# 4877173        NaN             NaN             56045
# 4877174        NaN             NaN             56045
#
#                             place_id        date  \
# 3812100  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 3812101  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 3812102  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 3812103  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 3812104  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                              ...         ...
# 4877170  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-01
# 4877171  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-02
# 4877172  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-05
# 4877173  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-06
# 4877174  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-07
#
#          retail_and_recreation_percent_change_from_baseline  \
# 3812100                                               6.00
# 3812101                                               7.00
# 3812102                                               6.00
# 3812103                                               0.00
# 3812104                                               2.00
# ...                                                    ...
# 4877170                                                nan
# 4877171                                                nan
# 4877172                                                nan
# 4877173                                                nan
# 4877174                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 3812100                                               2.00
# 3812101                                               1.00
# 3812102                                               0.00
# 3812103                                              -1.00
# 3812104                                               0.00
# ...                                                    ...
# 4877170                                                nan
# 4877171                                                nan
# 4877172                                                nan
# 4877173                                                nan
# 4877174                                                nan
#
#          parks_percent_change_from_baseline  \
# 3812100                               15.00
# 3812101                               16.00
# 3812102                               28.00
# 3812103                                6.00
# 3812104                                8.00
# ...                                     ...
# 4877170                                 nan
# 4877171                                 nan
# 4877172                                 nan
# 4877173                                 nan
# 4877174                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 3812100                                           3.00
# 3812101                                           2.00
# 3812102                                          -9.00
# 3812103                                           1.00
# 3812104                                           1.00
# ...                                                ...
# 4877170                                            nan
# 4877171                                            nan
# 4877172                                            nan
# 4877173                                            nan
# 4877174                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 3812100                                     2.00
# 3812101                                     0.00
# 3812102                                   -24.00
# 3812103                                     0.00
# 3812104                                     1.00
# ...                                          ...
# 4877170                                   -29.00
# 4877171                                   -34.00
# 4877172                                   -38.00
# 4877173                                   -23.00
# 4877174                                   -22.00
#
#          residential_percent_change_from_baseline
# 3812100                                     -1.00
# 3812101                                     -1.00
# 3812102                                      5.00
# 3812103                                      1.00
# 3812104                                      0.00
# ...                                           ...
# 4877170                                       nan
# 4877171                                       nan
# 4877172                                       nan
# 4877173                                       nan
# 4877174                                       nan
#
# [1065075 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
