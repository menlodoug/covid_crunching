# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
google_df = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)
google_df['census_fips_code'] = google_df['census_fips_code'].fillna(0).astype(np.int64)
google_df.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 4912901                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4912902                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4912903                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4912904                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 4912905                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 4912901        NaN             NaN                 0
# 4912902        NaN             NaN                 0
# 4912903        NaN             NaN                 0
# 4912904        NaN             NaN                 0
# 4912905        NaN             NaN                 0
#
#                             place_id        date  \
# 4912901  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-03-31
# 4912902  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-01
# 4912903  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-02
# 4912904  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-05
# 4912905  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-04-06
#
#          retail_and_recreation_percent_change_from_baseline  \
# 4912901                                                nan
# 4912902                                                nan
# 4912903                                                nan
# 4912904                                                nan
# 4912905                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 4912901                                                nan
# 4912902                                                nan
# 4912903                                                nan
# 4912904                                                nan
# 4912905                                                nan
#
#          parks_percent_change_from_baseline  \
# 4912901                                 nan
# 4912902                                 nan
# 4912903                                 nan
# 4912904                                 nan
# 4912905                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 4912901                                            nan
# 4912902                                            nan
# 4912903                                            nan
# 4912904                                            nan
# 4912905                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 4912901                                     5.00
# 4912902                                     0.00
# 4912903                                   -33.00
# 4912904                                   -54.00
# 4912905                                    10.00
#
#          residential_percent_change_from_baseline
# 4912901                                       nan
# 4912902                                       nan
# 4912903                                       nan
# 4912904                                       nan
# 4912905                                       nan

# %%
us_google = google_df[google_df['country_region'] == 'United States']
us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
us_google
# Out:
# <ipython-input-3-ef2a8e8188a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_google["sub_region_2"]= us_google["sub_region_2"].str.replace(" County", "")
#         country_region_code country_region sub_region_1 sub_region_2  \
# 3801903                  US  United States          NaN          NaN
# 3801904                  US  United States          NaN          NaN
# 3801905                  US  United States          NaN          NaN
# 3801906                  US  United States          NaN          NaN
# 3801907                  US  United States          NaN          NaN
# ...                     ...            ...          ...          ...
# 4864186                  US  United States      Wyoming       Weston
# 4864187                  US  United States      Wyoming       Weston
# 4864188                  US  United States      Wyoming       Weston
# 4864189                  US  United States      Wyoming       Weston
# 4864190                  US  United States      Wyoming       Weston
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 3801903        NaN             NaN                 0
# 3801904        NaN             NaN                 0
# 3801905        NaN             NaN                 0
# 3801906        NaN             NaN                 0
# 3801907        NaN             NaN                 0
# ...            ...             ...               ...
# 4864186        NaN             NaN             56045
# 4864187        NaN             NaN             56045
# 4864188        NaN             NaN             56045
# 4864189        NaN             NaN             56045
# 4864190        NaN             NaN             56045
#
#                             place_id        date  \
# 3801903  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 3801904  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 3801905  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 3801906  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 3801907  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                              ...         ...
# 4864186  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-03-31
# 4864187  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-01
# 4864188  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-02
# 4864189  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-05
# 4864190  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-04-06
#
#          retail_and_recreation_percent_change_from_baseline  \
# 3801903                                               6.00
# 3801904                                               7.00
# 3801905                                               6.00
# 3801906                                               0.00
# 3801907                                               2.00
# ...                                                    ...
# 4864186                                                nan
# 4864187                                                nan
# 4864188                                                nan
# 4864189                                                nan
# 4864190                                                nan
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 3801903                                               2.00
# 3801904                                               1.00
# 3801905                                               0.00
# 3801906                                              -1.00
# 3801907                                               0.00
# ...                                                    ...
# 4864186                                                nan
# 4864187                                                nan
# 4864188                                                nan
# 4864189                                                nan
# 4864190                                                nan
#
#          parks_percent_change_from_baseline  \
# 3801903                               15.00
# 3801904                               16.00
# 3801905                               28.00
# 3801906                                6.00
# 3801907                                8.00
# ...                                     ...
# 4864186                                 nan
# 4864187                                 nan
# 4864188                                 nan
# 4864189                                 nan
# 4864190                                 nan
#
#          transit_stations_percent_change_from_baseline  \
# 3801903                                           3.00
# 3801904                                           2.00
# 3801905                                          -9.00
# 3801906                                           1.00
# 3801907                                           1.00
# ...                                                ...
# 4864186                                            nan
# 4864187                                            nan
# 4864188                                            nan
# 4864189                                            nan
# 4864190                                            nan
#
#          workplaces_percent_change_from_baseline  \
# 3801903                                     2.00
# 3801904                                     0.00
# 3801905                                   -24.00
# 3801906                                     0.00
# 3801907                                     1.00
# ...                                          ...
# 4864186                                   -21.00
# 4864187                                   -29.00
# 4864188                                   -34.00
# 4864189                                   -38.00
# 4864190                                   -23.00
#
#          residential_percent_change_from_baseline
# 3801903                                     -1.00
# 3801904                                     -1.00
# 3801905                                      5.00
# 3801906                                      1.00
# 3801907                                      0.00
# ...                                           ...
# 4864186                                       nan
# 4864187                                       nan
# 4864188                                       nan
# 4864189                                       nan
# 4864190                                       nan
#
# [1062288 rows x 15 columns]

# %%
# us_google = us_google[['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'date', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline']]
# us_google

# %%
us_google.to_csv('us_google.csv', index=False)
