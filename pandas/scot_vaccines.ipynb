# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
scot_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/Scotland.csv')
scot_shot.tail()
# Out:
#      location        date                                       vaccine  \
# 463  Scotland  2022-05-07  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 464  Scotland  2022-05-08  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 465  Scotland  2022-05-09  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 466  Scotland  2022-05-10  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 467  Scotland  2022-05-11  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                             source_url  total_vaccinations  \
# 463  https://coronavirus.data.gov.uk/details/vaccin...            12234580
# 464  https://coronavirus.data.gov.uk/details/vaccin...            12237459
# 465  https://coronavirus.data.gov.uk/details/vaccin...            12239822
# 466  https://coronavirus.data.gov.uk/details/vaccin...            12241642
# 467  https://coronavirus.data.gov.uk/details/vaccin...            12243857
#
#      people_vaccinated  people_fully_vaccinated  total_boosters
# ...

# %%
scot_vac = scot_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
scot_vac.rename(columns={'location' : 'country'}, inplace=True)
scot_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            date  total_vaccinations  people_vaccinated  \
# 463  2022-05-07            12234580            4509766
# 464  2022-05-08            12237459            4510702
# 465  2022-05-09            12239822            4511017
# 466  2022-05-10            12241642            4511287
# 467  2022-05-11            12243857            4511645
#
#      people_fully_vaccinated   country
# 463                  4199979  Scotland
# 464                  4201056  Scotland
# 465                  4201682  Scotland
# 466                  4202119  Scotland
# 467                  4202683  Scotland

# %%
scot_vac.to_csv('scot_shot.csv', index=False)
