# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
scot_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/Scotland.csv')
scot_shot.tail()
# Out:
#     location        date                              vaccine  \
# 85  Scotland  2021-04-01  Oxford/AstraZeneca, Pfizer/BioNTech
# 86  Scotland  2021-04-02  Oxford/AstraZeneca, Pfizer/BioNTech
# 87  Scotland  2021-04-03  Oxford/AstraZeneca, Pfizer/BioNTech
# 88  Scotland  2021-04-04  Oxford/AstraZeneca, Pfizer/BioNTech
# 89  Scotland  2021-04-05  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                            source_url  total_vaccinations  \
# 85  https://coronavirus.data.gov.uk/details/health...             2930288
# 86  https://coronavirus.data.gov.uk/details/health...             2970830
# 87  https://coronavirus.data.gov.uk/details/health...             3004894
# 88  https://coronavirus.data.gov.uk/details/health...             3021654
# 89  https://coronavirus.data.gov.uk/details/health...             3041596
#
#     people_vaccinated  people_fully_vaccinated
# 85            2515748                   414540
# 86            2535889                   434941
# 87            2553837                   451057
# 88            2565280                   456374
# 89            2577816                   463780

# %%
scot_vac = scot_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
scot_vac.rename(columns={'location' : 'country'}, inplace=True)
scot_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           date  total_vaccinations  people_vaccinated  \
# 85  2021-04-01             2930288            2515748
# 86  2021-04-02             2970830            2535889
# 87  2021-04-03             3004894            2553837
# 88  2021-04-04             3021654            2565280
# 89  2021-04-05             3041596            2577816
#
#     people_fully_vaccinated   country
# 85                   414540  Scotland
# 86                   434941  Scotland
# 87                   451057  Scotland
# 88                   456374  Scotland
# 89                   463780  Scotland

# %%
scot_vac.to_csv('scot_shot.csv', index=False)
