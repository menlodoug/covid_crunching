# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
us_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv')
us_shot.tail()
# Out:
#            date       location  total_vaccinations  people_vaccinated  \
# 327  2021-11-05  United States           432294621          223940686
# 328  2021-11-06  United States           432948729          224172304
# 329  2021-11-07  United States           433098491          224234863
# 330  2021-11-08  United States           433156393          224257467
# 331  2021-11-09  United States           433156393          224257467
#
#      people_fully_vaccinated  total_boosters  \
# 327                192605504        24883078
# 328                192690568        25228659
# 329                192715085        25294990
# 330                192724988        25321058
# 331                192724988        25321058
#
#                                             source_url  \
# 327  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 328  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 329  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 330  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 331  https://covid.cdc.gov/covid-data-tracker/#vacc...
#
#                                        vaccine
# 327  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 328  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 329  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 330  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 331  Johnson&Johnson, Moderna, Pfizer/BioNTech
#            date       location  total_vaccinations  people_vaccinated  \
# 327  2021-11-05  United States           432294621          223940686
# 328  2021-11-06  United States           432948729          224172304
# 329  2021-11-07  United States           433098491          224234863
# 330  2021-11-08  United States           433156393          224257467
# 331  2021-11-09  United States           433156393          224257467
#
#      people_fully_vaccinated  total_boosters  \
# 327                192605504        24883078
# 328                192690568        25228659
# 329                192715085        25294990
# 330                192724988        25321058
# 331                192724988        25321058
#
#                                             source_url  \
# 327  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 328  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 329  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 330  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 331  https://covid.cdc.gov/covid-data-tracker/#vacc...
#
#                                        vaccine
# 327  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 328  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 329  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 330  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 331  Johnson&Johnson, Moderna, Pfizer/BioNTech

# %%
us_vac = us_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
us_vac.rename(columns={'location' : 'country'}, inplace=True)
us_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            date  total_vaccinations  people_vaccinated  \
# 327  2021-11-05           432294621          223940686
# 328  2021-11-06           432948729          224172304
# 329  2021-11-07           433098491          224234863
# 330  2021-11-08           433156393          224257467
# 331  2021-11-09           433156393          224257467
#
#      people_fully_vaccinated        country
# 327                192605504  United States
# 328                192690568  United States
# 329                192715085  United States
# 330                192724988  United States
# 331                192724988  United States
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            date  total_vaccinations  people_vaccinated  \
# 327  2021-11-05           432294621          223940686
# 328  2021-11-06           432948729          224172304
# 329  2021-11-07           433098491          224234863
# 330  2021-11-08           433156393          224257467
# 331  2021-11-09           433156393          224257467
#
#      people_fully_vaccinated        country
# 327                192605504  United States
# 328                192690568  United States
# 329                192715085  United States
# 330                192724988  United States
# 331                192724988  United States

# %%
us_vac.to_csv('us_shot.csv', index=False)
