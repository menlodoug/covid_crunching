# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
us_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv')
us_shot.tail()
# Out:
#          location        date                                    vaccine  \
# 78  United States  2021-03-22  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 79  United States  2021-03-23  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 80  United States  2021-03-24  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 81  United States  2021-03-25  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82  United States  2021-03-26  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                            source_url  total_vaccinations  \
# 78  https://covid.cdc.gov/covid-data-tracker/#vacc...           126509736
# 79  https://covid.cdc.gov/covid-data-tracker/#vacc...           128217029
# 80  https://covid.cdc.gov/covid-data-tracker/#vacc...           130473853
# 81  https://covid.cdc.gov/covid-data-tracker/#vacc...           133305295
# 82  https://covid.cdc.gov/covid-data-tracker/#vacc...           136684688
#
#     people_vaccinated  people_fully_vaccinated
# ...

# %%
us_vac = us_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
us_vac.rename(columns={'location' : 'country'}, inplace=True)
us_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           date  total_vaccinations  people_vaccinated  \
# 78  2021-03-22           126509736           82772416
# 79  2021-03-23           128217029           83930495
# 80  2021-03-24           130473853           85472166
# 81  2021-03-25           133305295           87343622
# 82  2021-03-26           136684688           89559225
#
#     people_fully_vaccinated        country
# 78                 44910946  United States
# 79                 45533962  United States
# 80                 46365515  United States
# 81                 47419832  United States
# 82                 48695172  United States

# %%
us_vac.to_csv('us_shot.csv', index=False)
