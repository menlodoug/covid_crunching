# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
us_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv')
us_shot.tail()
# Out:
#           location        date  \
# 740  United States  2022-12-23
# 741  United States  2022-12-24
# 742  United States  2022-12-25
# 743  United States  2022-12-26
# 744  United States  2022-12-27
#
#                                                vaccine  \
# 740  Johnson&Johnson, Moderna, Novavax, Pfizer/BioN...
# 741  Johnson&Johnson, Moderna, Novavax, Pfizer/BioN...
# 742  Johnson&Johnson, Moderna, Novavax, Pfizer/BioN...
# 743  Johnson&Johnson, Moderna, Novavax, Pfizer/BioN...
# 744  Johnson&Johnson, Moderna, Novavax, Pfizer/BioN...
#
#                                             source_url  total_vaccinations  \
# 740  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           663718981
# 741  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           663744840
# 742  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           663746477
# 743  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           663794258
# 744  https://data.cdc.gov/Vaccinations/COVID-19-Vac...           663822575
#
#      people_vaccinated  people_fully_vaccinated  total_boosters
# 740          268343376                229124707             nan
# 741          268348577                229127038             nan
# 742          268349580                229127144             nan
# 743          268358736                229131816             nan
# 744          268363272                229135170             nan

# %%
us_vac = us_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
us_vac.rename(columns={'location' : 'country'}, inplace=True)
us_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            date  total_vaccinations  people_vaccinated  \
# 740  2022-12-23           663718981          268343376
# 741  2022-12-24           663744840          268348577
# 742  2022-12-25           663746477          268349580
# 743  2022-12-26           663794258          268358736
# 744  2022-12-27           663822575          268363272
#
#      people_fully_vaccinated        country
# 740                229124707  United States
# 741                229127038  United States
# 742                229127144  United States
# 743                229131816  United States
# 744                229135170  United States

# %%
us_vac.to_csv('us_shot.csv', index=False)
