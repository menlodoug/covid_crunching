# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-08-16-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0   BPagano    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 1        UM    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 2  JHU-CSSE    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 3  Columbia    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 4   MIT-ORC    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  25031            2896          17244          32476
# 1  Alabama   01  23333           19368          21685          24525
# 2  Alabama   01  26102           20531          22332          27719
# 3  Alabama   01  29168           20156          25671          31627
# 4  Alabama   01  32858           23454          29622          36094
#
#    quantile_0.975
# 0           46825
# 1           27150
# 2           36294
# 3           38012
# 4           42262

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0   BPagano    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 1        UM    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 2  JHU-CSSE    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 3  Columbia    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
# 4   MIT-ORC    2021-08-16  1 wk ahead inc case      2021-08-21       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  25031            2896          17244          32476
# 1  Alabama   01  23333           19368          21685          24525
# 2  Alabama   01  26102           20531          22332          27719
# 3  Alabama   01  29168           20156          25671          31627
# 4  Alabama   01  32858           23454          29622          36094
#
#    quantile_0.975
# 0           46825
# 1           27150
# 2           36294
# 3           38012
# 4           42262

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 18       JHU-UNC-Google    2021-08-16  1 wk ahead inc case      2021-08-21
# 19             Columbia    2021-08-16  1 wk ahead inc case      2021-08-21
# 20             UGA-CEID    2021-08-16  1 wk ahead inc case      2021-08-21
# 21                 LANL    2021-08-16  1 wk ahead inc case      2021-08-21
# 22              JHU-APL    2021-08-16  1 wk ahead inc case      2021-08-21
# ...                 ...           ...                  ...             ...
# 103315          JHU-APL    2021-08-16  4 wk ahead inc case      2021-09-11
# 103316             LANL    2021-08-16  4 wk ahead inc case      2021-09-11
# 103317         Columbia    2021-08-16  4 wk ahead inc case      2021-09-11
# 103318  PandemicCentral    2021-08-16  4 wk ahead inc case      2021-09-11
# 103319   JHU-UNC-Google    2021-08-16  4 wk ahead inc case      2021-09-11
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 18           Autauga  Alabama  01001    222              41            166
# 19           Autauga  Alabama  01001    227             115            183
# 20           Autauga  Alabama  01001    189             131            169
# 21           Autauga  Alabama  01001    400             245            340
# 22           Autauga  Alabama  01001    185              97            148
# ...              ...      ...    ...    ...             ...            ...
# 103315        Weston  Wyoming  56045     15               3              9
# 103316        Weston  Wyoming  56045      8               1              5
# 103317        Weston  Wyoming  56045      0               0              0
# 103318        Weston  Wyoming  56045     14               2              5
# 103319        Weston  Wyoming  56045      7               0              0
#
#         quantile_0.75  quantile_0.975
# 18                333             543
# 19                270             381
# 20                207             271
# 21                469             618
# 22                232             324
# ...               ...             ...
# 103315             25              48
# 103316             11              17
# 103317              0              14
# 103318             18              34
# 103319             25             281
#
# [99288 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
