# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-07-26-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#            model forecast_date               target target_end_date  \
# 0  MIT-Cassandra    2021-07-26  1 wk ahead inc case      2021-07-31
# 1             UM    2021-07-26  1 wk ahead inc case      2021-07-31
# 2        JHU-APL    2021-07-26  1 wk ahead inc case      2021-07-31
# 3            UVA    2021-07-26  1 wk ahead inc case      2021-07-31
# 4      Microsoft    2021-07-26  1 wk ahead inc case      2021-07-31
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  14385            3462          10626
# 1       Alabama  Alabama   01   6651            4456           5343
# 2       Alabama  Alabama   01  11989            5065           8437
# 3       Alabama  Alabama   01  16177            3157          11696
# 4       Alabama  Alabama   01  13341           10579          12395
#
#    quantile_0.75  quantile_0.975
# 0          18144           25307
# 1           7104            9132
# 2          15986           23985
# 3          20657           29196
# 4          13817           18536

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#            model forecast_date               target target_end_date  \
# 0  MIT-Cassandra    2021-07-26  1 wk ahead inc case      2021-07-31
# 1             UM    2021-07-26  1 wk ahead inc case      2021-07-31
# 2        JHU-APL    2021-07-26  1 wk ahead inc case      2021-07-31
# 3            UVA    2021-07-26  1 wk ahead inc case      2021-07-31
# 4      Microsoft    2021-07-26  1 wk ahead inc case      2021-07-31
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  14385            3462          10626
# 1       Alabama  Alabama   01   6651            4456           5343
# 2       Alabama  Alabama   01  11989            5065           8437
# 3       Alabama  Alabama   01  16177            3157          11696
# 4       Alabama  Alabama   01  13341           10579          12395
#
#    quantile_0.75  quantile_0.975
# 0          18144           25307
# 1           7104            9132
# 2          15986           23985
# 3          20657           29196
# 4          13817           18536

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 21                  UVA    2021-07-26  1 wk ahead inc case      2021-07-31
# 22             Columbia    2021-07-26  1 wk ahead inc case      2021-07-31
# 23             Ensemble    2021-07-26  1 wk ahead inc case      2021-07-31
# 24      PandemicCentral    2021-07-26  1 wk ahead inc case      2021-07-31
# 25         FRBSF-Wilson    2021-07-26  1 wk ahead inc case      2021-07-31
# ...                 ...           ...                  ...             ...
# 123579  PandemicCentral    2021-07-26  4 wk ahead inc case      2021-08-21
# 123580          JHU-APL    2021-07-26  4 wk ahead inc case      2021-08-21
# 123581         Facebook    2021-07-26  4 wk ahead inc case      2021-08-21
# 123582         Columbia    2021-07-26  4 wk ahead inc case      2021-08-21
# 123583              UVA    2021-07-26  4 wk ahead inc case      2021-08-21
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 21           Autauga  Alabama  01001     61              38             53
# 22           Autauga  Alabama  01001     57              11             40
# 23           Autauga  Alabama  01001     58              26             40
# 24           Autauga  Alabama  01001     77              27             65
# 25           Autauga  Alabama  01001     38              12             27
# ...              ...      ...    ...    ...             ...            ...
# 123579        Weston  Wyoming  56045      2               0              0
# 123580        Weston  Wyoming  56045      2               0              1
# 123581        Weston  Wyoming  56045      9               0              0
# 123582        Weston  Wyoming  56045      0               0              0
# 123583        Weston  Wyoming  56045      5               0              2
#
#         quantile_0.75  quantile_0.975
# 21                 70              85
# 22                 82             146
# 23                 81             119
# 24                 88             119
# 25                 51             109
# ...               ...             ...
# 123579              3               6
# 123580              4               6
# 123581             25              53
# 123582              0              14
# 123583              8              12
#
# [118700 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
