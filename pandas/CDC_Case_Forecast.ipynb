# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-04-05-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  BPagano    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 1      IEM    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 2       UM    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 3  MIT-ORC    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 4      LNQ    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   2671            1055           2102           3215
# 1  Alabama   01   2450             689           1676           3343
# 2  Alabama   01   3620             107           2511           5109
# 3  Alabama   01   1883             324           1346           2420
# 4  Alabama   01   2236             570           1697           2775
#
#    quantile_0.975
# 0            4262
# 1            5353
# 2            8173
# 3            3442
# 4            4750

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  BPagano    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 1      IEM    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 2       UM    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 3  MIT-ORC    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
# 4      LNQ    2021-04-05  1 wk ahead inc case      2021-04-10       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   2671            1055           2102           3215
# 1  Alabama   01   2450             689           1676           3343
# 2  Alabama   01   3620             107           2511           5109
# 3  Alabama   01   1883             324           1346           2420
# 4  Alabama   01   2236             570           1697           2775
#
#    quantile_0.975
# 0            4262
# 1            5353
# 2            8173
# 3            3442
# 4            4750

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                model forecast_date               target target_end_date  \
# 23               LNQ    2021-04-05  1 wk ahead inc case      2021-04-10
# 24          Columbia    2021-04-05  1 wk ahead inc case      2021-04-10
# 25               ISU    2021-04-05  1 wk ahead inc case      2021-04-10
# 26           JHU-IDD    2021-04-05  1 wk ahead inc case      2021-04-10
# 27         UpstateSU    2021-04-05  1 wk ahead inc case      2021-04-10
# ...              ...           ...                  ...             ...
# 158271           LNQ    2021-04-05  4 wk ahead inc case      2021-05-01
# 158272  FRBSF-Wilson    2021-04-05  4 wk ahead inc case      2021-05-01
# 158273          LANL    2021-04-05  4 wk ahead inc case      2021-05-01
# 158274      UGA-CEID    2021-04-05  4 wk ahead inc case      2021-05-01
# 158275       JHU-IDD    2021-04-05  4 wk ahead inc case      2021-05-01
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 23           Autauga  Alabama  01001     38               2             21
# 24           Autauga  Alabama  01001     26               4             17
# 25           Autauga  Alabama  01001     54              41             50
# 26           Autauga  Alabama  01001     37               0              3
# 27           Autauga  Alabama  01001     55              50             53
# ...              ...      ...    ...    ...             ...            ...
# 158271        Weston  Wyoming  56045      0               0              0
# 158272        Weston  Wyoming  56045      0               0              0
# 158273        Weston  Wyoming  56045      1               0              0
# 158274        Weston  Wyoming  56045      2               0              0
# 158275        Weston  Wyoming  56045      2               0              0
#
#         quantile_0.75  quantile_0.975
# 23                 62             137
# 24                 36              63
# 25                 60              68
# 26                 37             244
# 27                 57              59
# ...               ...             ...
# 158271              6              42
# 158272              1               2
# 158273              3              12
# 158274             11              29
# 158275              1              15
#
# [153096 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
