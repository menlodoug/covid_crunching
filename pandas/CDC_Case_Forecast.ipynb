# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-05-17-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      model forecast_date               target target_end_date location_name  \
# 0  BPagano    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 1  JHU-IDD    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 2      ESG    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 3     MOBS    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 4     LANL    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   2134               0           1348           2886
# 1  Alabama   01   6995              43            474           6382
# 2  Alabama   01   3455            1414           2753           4157
# 3  Alabama   01   4709            2154           3545           6188
# 4  Alabama   01   1877             326            957           3448
#
#    quantile_0.975
# 0            4333
# 1           50140
# 2            5496
# 3            8844
# 4            8671

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  BPagano    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 1  JHU-IDD    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 2      ESG    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 3     MOBS    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
# 4     LANL    2021-05-17  1 wk ahead inc case      2021-05-22       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   2134               0           1348           2886
# 1  Alabama   01   6995              43            474           6382
# 2  Alabama   01   3455            1414           2753           4157
# 3  Alabama   01   4709            2154           3545           6188
# 4  Alabama   01   1877             326            957           3448
#
#    quantile_0.975
# 0            4333
# 1           50140
# 2            5496
# 3            8844
# 4            8671

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 21            Ensemble    2021-05-17  1 wk ahead inc case      2021-05-22
# 22            UGA-CEID    2021-05-17  1 wk ahead inc case      2021-05-22
# 23           UpstateSU    2021-05-17  1 wk ahead inc case      2021-05-22
# 24                 LNQ    2021-05-17  1 wk ahead inc case      2021-05-22
# 25      JHU-UNC-Google    2021-05-17  1 wk ahead inc case      2021-05-22
# ...                ...           ...                  ...             ...
# 148155        Facebook    2021-05-17  4 wk ahead inc case      2021-06-12
# 148156            LANL    2021-05-17  4 wk ahead inc case      2021-06-12
# 148157             UVA    2021-05-17  4 wk ahead inc case      2021-06-12
# 148158  JHU-UNC-Google    2021-05-17  4 wk ahead inc case      2021-06-12
# 148159        UGA-CEID    2021-05-17  4 wk ahead inc case      2021-06-12
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 21           Autauga  Alabama  01001     25               2             16
# 22           Autauga  Alabama  01001     90               0             45
# 23           Autauga  Alabama  01001     83              67             79
# 24           Autauga  Alabama  01001     43               4             21
# 25           Autauga  Alabama  01001     59               0             35
# ...              ...      ...    ...    ...             ...            ...
# 148155        Weston  Wyoming  56045      2               0              0
# 148156        Weston  Wyoming  56045      2               0              0
# 148157        Weston  Wyoming  56045      0               0              0
# 148158        Weston  Wyoming  56045      0               0              0
# 148159        Weston  Wyoming  56045      0               0              0
#
#         quantile_0.75  quantile_0.975
# 21                 56             110
# 22                129             273
# 23                 90              95
# 24                 73             184
# 25                 95             182
# ...               ...             ...
# 148155              8              17
# 148156              3               8
# 148157              1               2
# 148158              7              22
# 148159              4              10
#
# [143148 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
