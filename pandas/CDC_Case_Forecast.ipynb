# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-08-23-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0     BPagano    2021-08-23  1 wk ahead inc case      2021-08-28
# 1  MIT-ISOLAT    2021-08-23  1 wk ahead inc case      2021-08-28
# 2    Ensemble    2021-08-23  1 wk ahead inc case      2021-08-28
# 3        MOBS    2021-08-23  1 wk ahead inc case      2021-08-28
# 4  Covid19Sim    2021-08-23  1 wk ahead inc case      2021-08-28
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  30946            3580          21319
# 1       Alabama  Alabama   01  24783               0          16254
# 2       Alabama  Alabama   01  28246           18476          25183
# 3       Alabama  Alabama   01  24621           14563          21076
# 4       Alabama  Alabama   01  27495           27198          27460
#
#    quantile_0.75  quantile_0.975
# 0          40151           57890
# 1          33312           49566
# 2          33373           40149
# 3          28185           36199
# 4          27556           28555

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0     BPagano    2021-08-23  1 wk ahead inc case      2021-08-28
# 1  MIT-ISOLAT    2021-08-23  1 wk ahead inc case      2021-08-28
# 2    Ensemble    2021-08-23  1 wk ahead inc case      2021-08-28
# 3        MOBS    2021-08-23  1 wk ahead inc case      2021-08-28
# 4  Covid19Sim    2021-08-23  1 wk ahead inc case      2021-08-28
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  30946            3580          21319
# 1       Alabama  Alabama   01  24783               0          16254
# 2       Alabama  Alabama   01  28246           18476          25183
# 3       Alabama  Alabama   01  24621           14563          21076
# 4       Alabama  Alabama   01  27495           27198          27460
#
#    quantile_0.75  quantile_0.975
# 0          40151           57890
# 1          33312           49566
# 2          33373           40149
# 3          28185           36199
# 4          27556           28555

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 21            Columbia    2021-08-23  1 wk ahead inc case      2021-08-28
# 22        FRBSF-Wilson    2021-08-23  1 wk ahead inc case      2021-08-28
# 23      JHU-UNC-Google    2021-08-23  1 wk ahead inc case      2021-08-28
# 24            UGA-CEID    2021-08-23  1 wk ahead inc case      2021-08-28
# 25            Facebook    2021-08-23  1 wk ahead inc case      2021-08-28
# ...                ...           ...                  ...             ...
# 111311        Ensemble    2021-08-23  4 wk ahead inc case      2021-09-18
# 111312        Columbia    2021-08-23  4 wk ahead inc case      2021-09-18
# 111313        UGA-CEID    2021-08-23  4 wk ahead inc case      2021-09-18
# 111314  JHU-UNC-Google    2021-08-23  4 wk ahead inc case      2021-09-18
# 111315             UVA    2021-08-23  4 wk ahead inc case      2021-09-18
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 21           Autauga  Alabama  01001    235             112            189
# 22           Autauga  Alabama  01001    207              72            152
# 23           Autauga  Alabama  01001    280              23            233
# 24           Autauga  Alabama  01001    191             107            161
# 25           Autauga  Alabama  01001    199              22            138
# ...              ...      ...    ...    ...             ...            ...
# 111311        Weston  Wyoming  56045     18               0              8
# 111312        Weston  Wyoming  56045      0               0              0
# 111313        Weston  Wyoming  56045     11               0              5
# 111314        Weston  Wyoming  56045     27               0              7
# 111315        Weston  Wyoming  56045    173             161            168
#
#         quantile_0.75  quantile_0.975
# 21                279             379
# 22                280             591
# 23                425            2523
# 24                216             309
# 25                260             376
# ...               ...             ...
# 111311             32              72
# 111312              1              14
# 111313             17              28
# 111314             64             199
# 111315            178             185
#
# [106604 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
