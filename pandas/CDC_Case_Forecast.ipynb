# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-10-18-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#            model forecast_date               target target_end_date  \
# 0            UVA    2021-10-18  1 wk ahead inc case      2021-10-23
# 1            ESG    2021-10-18  1 wk ahead inc case      2021-10-23
# 2        BPagano    2021-10-18  1 wk ahead inc case      2021-10-23
# 3        MIT-ORC    2021-10-18  1 wk ahead inc case      2021-10-23
# 4  MIT-Cassandra    2021-10-18  1 wk ahead inc case      2021-10-23
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   5218               0           2326
# 1       Alabama  Alabama   01   3835               0           1958
# 2       Alabama  Alabama   01   3818            1297           2931
# 3       Alabama  Alabama   01   2447             135           1651
# 4       Alabama  Alabama   01   5346               0              0
#
#    quantile_0.75  quantile_0.975
# 0           8110           13621
# 1           5712            9291
# 2           4666            6300
# 3           3243            4759
# 4          31825           82290

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#            model forecast_date               target target_end_date  \
# 0            UVA    2021-10-18  1 wk ahead inc case      2021-10-23
# 1            ESG    2021-10-18  1 wk ahead inc case      2021-10-23
# 2        BPagano    2021-10-18  1 wk ahead inc case      2021-10-23
# 3        MIT-ORC    2021-10-18  1 wk ahead inc case      2021-10-23
# 4  MIT-Cassandra    2021-10-18  1 wk ahead inc case      2021-10-23
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   5218               0           2326
# 1       Alabama  Alabama   01   3835               0           1958
# 2       Alabama  Alabama   01   3818            1297           2931
# 3       Alabama  Alabama   01   2447             135           1651
# 4       Alabama  Alabama   01   5346               0              0
#
#    quantile_0.75  quantile_0.975
# 0           8110           13621
# 1           5712            9291
# 2           4666            6300
# 3           3243            4759
# 4          31825           82290

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 15            Ensemble    2021-10-18  1 wk ahead inc case      2021-10-23
# 16           CUBoulder    2021-10-18  1 wk ahead inc case      2021-10-23
# 17            Columbia    2021-10-18  1 wk ahead inc case      2021-10-23
# 18                 UVA    2021-10-18  1 wk ahead inc case      2021-10-23
# 19     PandemicCentral    2021-10-18  1 wk ahead inc case      2021-10-23
# ...                ...           ...                  ...             ...
# 97263        CUBoulder    2021-10-18  4 wk ahead inc case      2021-11-13
# 97264              UVA    2021-10-18  4 wk ahead inc case      2021-11-13
# 97265  PandemicCentral    2021-10-18  4 wk ahead inc case      2021-11-13
# 97266          JHU-APL    2021-10-18  4 wk ahead inc case      2021-11-13
# 97267         Facebook    2021-10-18  4 wk ahead inc case      2021-11-13
#
#       location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 15          Autauga  Alabama  01001     44               9             31
# 16          Autauga  Alabama  01001     37              21             30
# 17          Autauga  Alabama  01001     37               4             23
# 18          Autauga  Alabama  01001     23               0              8
# 19          Autauga  Alabama  01001     73              15             34
# ...             ...      ...    ...    ...             ...            ...
# 97263        Weston  Wyoming  56045     20               3             13
# 97264        Weston  Wyoming  56045     22               0              7
# 97265        Weston  Wyoming  56045     37               4             11
# 97266        Weston  Wyoming  56045     15               5             10
# 97267        Weston  Wyoming  56045     10               0              0
#
#        quantile_0.75  quantile_0.975
# 15                64             122
# 16                43              65
# 17                49              89
# 18                39              66
# 19               105             154
# ...              ...             ...
# 97263             32              56
# 97264             38              67
# 97265             50              92
# 97266             21              35
# 97267             26              56
#
# [93880 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
