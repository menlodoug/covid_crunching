# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-11-08-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0         IEM    2021-11-08  1 wk ahead inc case      2021-11-13
# 1         USC    2021-11-08  1 wk ahead inc case      2021-11-13
# 2      Karlen    2021-11-08  1 wk ahead inc case      2021-11-13
# 3  MIT-ISOLAT    2021-11-08  1 wk ahead inc case      2021-11-13
# 4          UM    2021-11-08  1 wk ahead inc case      2021-11-13
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   4550            1088           3223
# 1       Alabama  Alabama   01   6495            5094           5915
# 2       Alabama  Alabama   01   3431            2067           2926
# 3       Alabama  Alabama   01    884               0            579
# 4       Alabama  Alabama   01   9727            5442           8157
#
#    quantile_0.75  quantile_0.975
# 0           5806            8298
# 1           7091            8255
# 2           4116            5468
# 3           1188            1768
# 4          11509           14797

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0         IEM    2021-11-08  1 wk ahead inc case      2021-11-13
# 1         USC    2021-11-08  1 wk ahead inc case      2021-11-13
# 2      Karlen    2021-11-08  1 wk ahead inc case      2021-11-13
# 3  MIT-ISOLAT    2021-11-08  1 wk ahead inc case      2021-11-13
# 4          UM    2021-11-08  1 wk ahead inc case      2021-11-13
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   4550            1088           3223
# 1       Alabama  Alabama   01   6495            5094           5915
# 2       Alabama  Alabama   01   3431            2067           2926
# 3       Alabama  Alabama   01    884               0            579
# 4       Alabama  Alabama   01   9727            5442           8157
#
#    quantile_0.75  quantile_0.975
# 0           5806            8298
# 1           7091            8255
# 2           4116            5468
# 3           1188            1768
# 4          11509           14797

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 16            Columbia    2021-11-08  1 wk ahead inc case      2021-11-13
# 17            Ensemble    2021-11-08  1 wk ahead inc case      2021-11-13
# 18      JHU-UNC-Google    2021-11-08  1 wk ahead inc case      2021-11-13
# 19        FRBSF-Wilson    2021-11-08  1 wk ahead inc case      2021-11-13
# 20     PandemicCentral    2021-11-08  1 wk ahead inc case      2021-11-13
# ...                ...           ...                  ...             ...
# 97355  PandemicCentral    2021-11-08  4 wk ahead inc case      2021-12-04
# 97356         Facebook    2021-11-08  4 wk ahead inc case      2021-12-04
# 97357        CUBoulder    2021-11-08  4 wk ahead inc case      2021-12-04
# 97358         Columbia    2021-11-08  4 wk ahead inc case      2021-12-04
# 97359   JHU-UNC-Google    2021-11-08  4 wk ahead inc case      2021-12-04
#
#       location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 16          Autauga  Alabama  01001    128              40             91
# 17          Autauga  Alabama  01001     96              31             81
# 18          Autauga  Alabama  01001     76               0             47
# 19          Autauga  Alabama  01001    201              93            161
# 20          Autauga  Alabama  01001     98              24             78
# ...             ...      ...    ...    ...             ...            ...
# 97355        Weston  Wyoming  56045     19               0              5
# 97356        Weston  Wyoming  56045     21               0              0
# 97357        Weston  Wyoming  56045     20               5             13
# 97358        Weston  Wyoming  56045      7               0              0
# 97359        Weston  Wyoming  56045     28               0              7
#
#        quantile_0.75  quantile_0.975
# 16               174             254
# 17               121             211
# 18               122             179
# 19               250             436
# 20               120             183
# ...              ...             ...
# 97355             27              59
# 97356             46              93
# 97357             31              69
# 97358             14              35
# 97359             61             137
#
# [93780 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
