# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-08-30-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        model forecast_date               target target_end_date location_name  \
# 0        USC    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 1         UM    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 2  Microsoft    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 3    BPagano    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 4   Ensemble    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  26630           22176          24564          29185
# 1  Alabama   01  30946           24928          28957          32935
# 2  Alabama   01  30435           24405          27472          31577
# 3  Alabama   01  26914            3113          18541          34919
# 4  Alabama   01  26680           16168          22748          31577
#
#    quantile_0.975
# 0           31043
# 1           37577
# 2           38550
# 3           50347
# 4           40281

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#        model forecast_date               target target_end_date location_name  \
# 0        USC    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 1         UM    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 2  Microsoft    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 3    BPagano    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
# 4   Ensemble    2021-08-30  1 wk ahead inc case      2021-09-04       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  26630           22176          24564          29185
# 1  Alabama   01  30946           24928          28957          32935
# 2  Alabama   01  30435           24405          27472          31577
# 3  Alabama   01  26914            3113          18541          34919
# 4  Alabama   01  26680           16168          22748          31577
#
#    quantile_0.975
# 0           31043
# 1           37577
# 2           38550
# 3           50347
# 4           40281

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 21                 LANL    2021-08-30  1 wk ahead inc case      2021-09-04
# 22             Columbia    2021-08-30  1 wk ahead inc case      2021-09-04
# 23         FRBSF-Wilson    2021-08-30  1 wk ahead inc case      2021-09-04
# 24       JHU-UNC-Google    2021-08-30  1 wk ahead inc case      2021-09-04
# 25             Ensemble    2021-08-30  1 wk ahead inc case      2021-09-04
# ...                 ...           ...                  ...             ...
# 135707              UVA    2021-08-30  4 wk ahead inc case      2021-09-25
# 135708         UGA-CEID    2021-08-30  4 wk ahead inc case      2021-09-25
# 135709          JHU-APL    2021-08-30  4 wk ahead inc case      2021-09-25
# 135710         Columbia    2021-08-30  4 wk ahead inc case      2021-09-25
# 135711  PandemicCentral    2021-08-30  4 wk ahead inc case      2021-09-25
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 21           Autauga  Alabama  01001    297              96            211
# 22           Autauga  Alabama  01001    224             127            189
# 23           Autauga  Alabama  01001    244              70            169
# 24           Autauga  Alabama  01001    292               5            229
# 25           Autauga  Alabama  01001    303             122            220
# ...              ...      ...    ...    ...             ...            ...
# 135707        Weston  Wyoming  56045     62               0             27
# 135708        Weston  Wyoming  56045     13               0              6
# 135709        Weston  Wyoming  56045     21               6             13
# 135710        Weston  Wyoming  56045      0               0              0
# 135711        Weston  Wyoming  56045     46               1             22
#
#         quantile_0.75  quantile_0.975
# 21                397             660
# 22                266             339
# 23                350             865
# 24                463           11976
# 25                364             496
# ...               ...             ...
# 135707             97             163
# 135708             18              26
# 135709             31              60
# 135710              2              14
# 135711             68             101
#
# [130968 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
