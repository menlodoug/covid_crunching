# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-06-07-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       model forecast_date               target target_end_date location_name  \
# 0   Masaryk    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 1  Ensemble    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 2   BPagano    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 3       ESG    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 4      LANL    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01    175               0              5            378
# 1  Alabama   01   1620             806           1212           2240
# 2  Alabama   01    655               0            414            886
# 3  Alabama   01   1567               0            761           2373
# 4  Alabama   01     29               0              0            359
#
#    quantile_0.975
# 0            1037
# 1            3386
# 2            1330
# 3            3910
# 4            3637

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0   Masaryk    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 1  Ensemble    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 2   BPagano    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 3       ESG    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
# 4      LANL    2021-06-07  1 wk ahead inc case      2021-06-12       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01    175               0              5            378
# 1  Alabama   01   1620             806           1212           2240
# 2  Alabama   01    655               0            414            886
# 3  Alabama   01   1567               0            761           2373
# 4  Alabama   01     29               0              0            359
#
#    quantile_0.975
# 0            1037
# 1            3386
# 2            1330
# 3            3910
# 4            3637

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 24       JHU-UNC-Google    2021-06-07  1 wk ahead inc case      2021-06-12
# 25             Ensemble    2021-06-07  1 wk ahead inc case      2021-06-12
# 26              JHU-APL    2021-06-07  1 wk ahead inc case      2021-06-12
# 27      PandemicCentral    2021-06-07  1 wk ahead inc case      2021-06-12
# 28                  LNQ    2021-06-07  1 wk ahead inc case      2021-06-12
# ...                 ...           ...                  ...             ...
# 137495              LNQ    2021-06-07  4 wk ahead inc case      2021-07-03
# 137496             LANL    2021-06-07  4 wk ahead inc case      2021-07-03
# 137497         Columbia    2021-06-07  4 wk ahead inc case      2021-07-03
# 137498         UGA-CEID    2021-06-07  4 wk ahead inc case      2021-07-03
# 137499  PandemicCentral    2021-06-07  4 wk ahead inc case      2021-07-03
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 24           Autauga  Alabama  01001     40               0             16
# 25           Autauga  Alabama  01001     44               0             14
# 26           Autauga  Alabama  01001     17              10             14
# 27           Autauga  Alabama  01001     59              28             44
# 28           Autauga  Alabama  01001     19               0              6
# ...              ...      ...    ...    ...             ...            ...
# 137495        Weston  Wyoming  56045      0               0              0
# 137496        Weston  Wyoming  56045      1               0              0
# 137497        Weston  Wyoming  56045      0               0              0
# 137498        Weston  Wyoming  56045      1               0              0
# 137499        Weston  Wyoming  56045      5               0              0
#
#         quantile_0.75  quantile_0.975
# 24                 79             160
# 25                 71             119
# 26                 21              30
# 27                 71             107
# 28                 43             119
# ...               ...             ...
# 137495              2              18
# 137496              2               4
# 137497              0              14
# 137498              3               7
# 137499              8              19
#
# [132104 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
