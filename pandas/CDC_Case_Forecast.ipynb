# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-08-02-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0     JHU-APL    2021-08-02  1 wk ahead inc case      2021-08-07
# 1     JHU-IDD    2021-08-02  1 wk ahead inc case      2021-08-07
# 2     BPagano    2021-08-02  1 wk ahead inc case      2021-08-07
# 3  Covid19Sim    2021-08-02  1 wk ahead inc case      2021-08-07
# 4  MIT-ISOLAT    2021-08-02  1 wk ahead inc case      2021-08-07
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  10455            5547           8297
# 1       Alabama  Alabama   01  13417             627           2644
# 2       Alabama  Alabama   01  21848               0          13809
# 3       Alabama  Alabama   01  14087           13546          13997
# 4       Alabama  Alabama   01  14171               0           9294
#
#    quantile_0.75  quantile_0.975
# 0          12776           17944
# 1          18680           54677
# 2          29536           44351
# 3          14145           14207
# 4          19048           28342

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0     JHU-APL    2021-08-02  1 wk ahead inc case      2021-08-07
# 1     JHU-IDD    2021-08-02  1 wk ahead inc case      2021-08-07
# 2     BPagano    2021-08-02  1 wk ahead inc case      2021-08-07
# 3  Covid19Sim    2021-08-02  1 wk ahead inc case      2021-08-07
# 4  MIT-ISOLAT    2021-08-02  1 wk ahead inc case      2021-08-07
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  10455            5547           8297
# 1       Alabama  Alabama   01  13417             627           2644
# 2       Alabama  Alabama   01  21848               0          13809
# 3       Alabama  Alabama   01  14087           13546          13997
# 4       Alabama  Alabama   01  14171               0           9294
#
#    quantile_0.75  quantile_0.975
# 0          12776           17944
# 1          18680           54677
# 2          29536           44351
# 3          14145           14207
# 4          19048           28342

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 21     PandemicCentral    2021-08-02  1 wk ahead inc case      2021-08-07
# 22            Columbia    2021-08-02  1 wk ahead inc case      2021-08-07
# 23            Ensemble    2021-08-02  1 wk ahead inc case      2021-08-07
# 24                LANL    2021-08-02  1 wk ahead inc case      2021-08-07
# 25             JHU-APL    2021-08-02  1 wk ahead inc case      2021-08-07
# ...                ...           ...                  ...             ...
# 98723             LANL    2021-08-02  4 wk ahead inc case      2021-08-28
# 98724         Ensemble    2021-08-02  4 wk ahead inc case      2021-08-28
# 98725  PandemicCentral    2021-08-02  4 wk ahead inc case      2021-08-28
# 98726         Columbia    2021-08-02  4 wk ahead inc case      2021-08-28
# 98727              UVA    2021-08-02  4 wk ahead inc case      2021-08-28
#
#       location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 21          Autauga  Alabama  01001    120              69             79
# 22          Autauga  Alabama  01001     98              28             71
# 23          Autauga  Alabama  01001    104              35             75
# 24          Autauga  Alabama  01001    255              74            177
# 25          Autauga  Alabama  01001     80              42             63
# ...             ...      ...    ...    ...             ...            ...
# 98723        Weston  Wyoming  56045      4               0              2
# 98724        Weston  Wyoming  56045      5               0              2
# 98725        Weston  Wyoming  56045     11               0              0
# 98726        Weston  Wyoming  56045      0               0              0
# 98727        Weston  Wyoming  56045     15               7             12
#
#        quantile_0.75  quantile_0.975
# 21               151             192
# 22               134             210
# 23               143             212
# 24               334             505
# 25                99             140
# ...              ...             ...
# 98723              7              14
# 98724              8              23
# 98725              7              80
# 98726              0              14
# 98727             18              23
#
# [94080 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
