# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-09-20-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  BPagano    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 1       UM    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 2      ESG    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 3     UCLA    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 4  JHU-APL    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  20385            6927          15651          24912
# 1  Alabama   01  28753           24623          27197          30116
# 2  Alabama   01  23908           12460          19970          27845
# 3  Alabama   01  17104           16804          16964          17312
# 4  Alabama   01  18635           10886          15406          22229
#
#    quantile_0.975
# 0           33636
# 1           34718
# 2           35356
# 3           18100
# 4           30151

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  BPagano    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 1       UM    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 2      ESG    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 3     UCLA    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
# 4  JHU-APL    2021-09-20  1 wk ahead inc case      2021-09-25       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  20385            6927          15651          24912
# 1  Alabama   01  28753           24623          27197          30116
# 2  Alabama   01  23908           12460          19970          27845
# 3  Alabama   01  17104           16804          16964          17312
# 4  Alabama   01  18635           10886          15406          22229
#
#    quantile_0.975
# 0           33636
# 1           34718
# 2           35356
# 3           18100
# 4           30151

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 20         FRBSF-Wilson    2021-09-20  1 wk ahead inc case      2021-09-25
# 21             Columbia    2021-09-20  1 wk ahead inc case      2021-09-25
# 22             UGA-CEID    2021-09-20  1 wk ahead inc case      2021-09-25
# 23             Facebook    2021-09-20  1 wk ahead inc case      2021-09-25
# 24              JHU-APL    2021-09-20  1 wk ahead inc case      2021-09-25
# ...                 ...           ...                  ...             ...
# 122911        CUBoulder    2021-09-20  4 wk ahead inc case      2021-10-16
# 122912         UGA-CEID    2021-09-20  4 wk ahead inc case      2021-10-16
# 122913         Columbia    2021-09-20  4 wk ahead inc case      2021-10-16
# 122914              UVA    2021-09-20  4 wk ahead inc case      2021-10-16
# 122915  PandemicCentral    2021-09-20  4 wk ahead inc case      2021-10-16
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 20           Autauga  Alabama  01001    300              96            216
# 21           Autauga  Alabama  01001    179              88            146
# 22           Autauga  Alabama  01001    249             221            239
# 23           Autauga  Alabama  01001    183               0            116
# 24           Autauga  Alabama  01001    154              91            128
# ...              ...      ...    ...    ...             ...            ...
# 122911        Weston  Wyoming  56045     18               4             10
# 122912        Weston  Wyoming  56045     24               7             17
# 122913        Weston  Wyoming  56045      0               0              0
# 122914        Weston  Wyoming  56045     18              13             16
# 122915        Weston  Wyoming  56045     22               6             16
#
#         quantile_0.75  quantile_0.975
# 20                414             955
# 21                215             277
# 22                257             287
# 23                249             375
# 24                184             249
# ...               ...             ...
# 122911             25              54
# 122912             29              43
# 122913              0              14
# 122914             20              22
# 122915             25              53
#
# [118404 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
