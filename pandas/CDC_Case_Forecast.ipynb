# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-04-12-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0       ESG    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 1  Ensemble    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 2       USC    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 3   JHU-IDD    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 4  UGA-CEID    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   1927             221           1340           2513
# 1  Alabama   01   1927             636           1437           2449
# 2  Alabama   01   1721            1488           1602           1832
# 3  Alabama   01   4887            1514           2781           5962
# 4  Alabama   01   1431               0              0           3765
#
#    quantile_0.975
# 0            3632
# 1            3632
# 2            2327
# 3           13632
# 4            7313

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0       ESG    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 1  Ensemble    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 2       USC    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 3   JHU-IDD    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
# 4  UGA-CEID    2021-04-12  1 wk ahead inc case      2021-04-17       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   1927             221           1340           2513
# 1  Alabama   01   1927             636           1437           2449
# 2  Alabama   01   1721            1488           1602           1832
# 3  Alabama   01   4887            1514           2781           5962
# 4  Alabama   01   1431               0              0           3765
#
#    quantile_0.975
# 0            3632
# 1            3632
# 2            2327
# 3           13632
# 4            7313

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 23                LANL    2021-04-12  1 wk ahead inc case      2021-04-17
# 24      JHU-UNC-Google    2021-04-12  1 wk ahead inc case      2021-04-17
# 25            Columbia    2021-04-12  1 wk ahead inc case      2021-04-17
# 26                 ISU    2021-04-12  1 wk ahead inc case      2021-04-17
# 27           UpstateSU    2021-04-12  1 wk ahead inc case      2021-04-17
# ...                ...           ...                  ...             ...
# 149747             LNQ    2021-04-12  4 wk ahead inc case      2021-05-08
# 149748         JHU-IDD    2021-04-12  4 wk ahead inc case      2021-05-08
# 149749        Facebook    2021-04-12  4 wk ahead inc case      2021-05-08
# 149750             ISU    2021-04-12  4 wk ahead inc case      2021-05-08
# 149751             UVA    2021-04-12  4 wk ahead inc case      2021-05-08
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 23           Autauga  Alabama  01001     59              13             35
# 24           Autauga  Alabama  01001     52               0             29
# 25           Autauga  Alabama  01001     50              17             36
# 26           Autauga  Alabama  01001     49              37             45
# 27           Autauga  Alabama  01001     93              87             88
# ...              ...      ...    ...    ...             ...            ...
# 149747        Weston  Wyoming  56045      3               0              0
# 149748        Weston  Wyoming  56045     11               0              0
# 149749        Weston  Wyoming  56045      5               0              0
# 149750        Weston  Wyoming  56045      2               0              1
# 149751        Weston  Wyoming  56045     33               0             16
#
#         quantile_0.75  quantile_0.975
# 23                 94             194
# 24                132             248
# 25                 64              93
# 26                 54              64
# 27                 95              97
# ...               ...             ...
# 149747             12              59
# 149748              5             109
# 149749             14              30
# 149750              3               6
# 149751             50              82
#
# [144540 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
