# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-06-28-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0  Ensemble    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 1       UVA    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 2    Karlen    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 3   BPagano    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 4   MIT-ORC    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   1023             284            652           1340
# 1  Alabama   01   1353               0            671           2036
# 2  Alabama   01   1246             643           1007           1603
# 3  Alabama   01   1209               0            764           1635
# 4  Alabama   01    609               0            235            983
#
#    quantile_0.975
# 0            2095
# 1            3335
# 2            2357
# 3            2455
# 4            1694

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0  Ensemble    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 1       UVA    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 2    Karlen    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 3   BPagano    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
# 4   MIT-ORC    2021-06-28  1 wk ahead inc case      2021-07-03       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   1023             284            652           1340
# 1  Alabama   01   1353               0            671           2036
# 2  Alabama   01   1246             643           1007           1603
# 3  Alabama   01   1209               0            764           1635
# 4  Alabama   01    609               0            235            983
#
#    quantile_0.975
# 0            2095
# 1            3335
# 2            2357
# 3            2455
# 4            1694

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 22         FRBSF-Wilson    2021-06-28  1 wk ahead inc case      2021-07-03
# 23             Columbia    2021-06-28  1 wk ahead inc case      2021-07-03
# 24             UGA-CEID    2021-06-28  1 wk ahead inc case      2021-07-03
# 25             Facebook    2021-06-28  1 wk ahead inc case      2021-07-03
# 26                 LANL    2021-06-28  1 wk ahead inc case      2021-07-03
# ...                 ...           ...                  ...             ...
# 124059         UGA-CEID    2021-06-28  4 wk ahead inc case      2021-07-24
# 124060         Columbia    2021-06-28  4 wk ahead inc case      2021-07-24
# 124061  PandemicCentral    2021-06-28  4 wk ahead inc case      2021-07-24
# 124062             LANL    2021-06-28  4 wk ahead inc case      2021-07-24
# 124063              UVA    2021-06-28  4 wk ahead inc case      2021-07-24
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 22           Autauga  Alabama  01001     18               6             13
# 23           Autauga  Alabama  01001      1               0              0
# 24           Autauga  Alabama  01001      5               0              0
# 25           Autauga  Alabama  01001     18               0              4
# 26           Autauga  Alabama  01001     24               3             15
# ...              ...      ...    ...    ...             ...            ...
# 124059        Weston  Wyoming  56045      0               0              0
# 124060        Weston  Wyoming  56045      0               0              0
# 124061        Weston  Wyoming  56045      3               0              0
# 124062        Weston  Wyoming  56045      1               0              0
# 124063        Weston  Wyoming  56045      0               0              0
#
#         quantile_0.75  quantile_0.975
# 22                 24              47
# 23                  7              20
# 24                 13              45
# 25                 32              57
# 26                 34              53
# ...               ...             ...
# 124059              1               3
# 124060              0              14
# 124061              5              10
# 124062              1               4
# 124063              1               1
#
# [119136 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
