# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-09-13-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0  MIT-ISOLAT    2021-09-13  1 wk ahead inc case      2021-09-18
# 1     JHU-IDD    2021-09-13  1 wk ahead inc case      2021-09-18
# 2         UVA    2021-09-13  1 wk ahead inc case      2021-09-18
# 3        MOBS    2021-09-13  1 wk ahead inc case      2021-09-18
# 4     JHU-APL    2021-09-13  1 wk ahead inc case      2021-09-18
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  24378           11373          19902
# 1       Alabama  Alabama   01  28247            4794          13070
# 2       Alabama  Alabama   01  23056            6157          17240
# 3       Alabama  Alabama   01  28002           20881          25090
# 4       Alabama  Alabama   01  17325            8940          13700
#
#    quantile_0.75  quantile_0.975
# 0          28854           37384
# 1          30484           98078
# 2          28871           39954
# 3          30349           34521
# 4          21639           31539

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0  MIT-ISOLAT    2021-09-13  1 wk ahead inc case      2021-09-18
# 1     JHU-IDD    2021-09-13  1 wk ahead inc case      2021-09-18
# 2         UVA    2021-09-13  1 wk ahead inc case      2021-09-18
# 3        MOBS    2021-09-13  1 wk ahead inc case      2021-09-18
# 4     JHU-APL    2021-09-13  1 wk ahead inc case      2021-09-18
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01  24378           11373          19902
# 1       Alabama  Alabama   01  28247            4794          13070
# 2       Alabama  Alabama   01  23056            6157          17240
# 3       Alabama  Alabama   01  28002           20881          25090
# 4       Alabama  Alabama   01  17325            8940          13700
#
#    quantile_0.75  quantile_0.975
# 0          28854           37384
# 1          30484           98078
# 2          28871           39954
# 3          30349           34521
# 4          21639           31539

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 20         FRBSF-Wilson    2021-09-13  1 wk ahead inc case      2021-09-18
# 21             Ensemble    2021-09-13  1 wk ahead inc case      2021-09-18
# 22                 LANL    2021-09-13  1 wk ahead inc case      2021-09-18
# 23            CUBoulder    2021-09-13  1 wk ahead inc case      2021-09-18
# 24              JHU-APL    2021-09-13  1 wk ahead inc case      2021-09-18
# ...                 ...           ...                  ...             ...
# 110519  PandemicCentral    2021-09-13  4 wk ahead inc case      2021-10-09
# 110520              UVA    2021-09-13  4 wk ahead inc case      2021-10-09
# 110521        CUBoulder    2021-09-13  4 wk ahead inc case      2021-10-09
# 110522         Columbia    2021-09-13  4 wk ahead inc case      2021-10-09
# 110523          JHU-APL    2021-09-13  4 wk ahead inc case      2021-10-09
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 20           Autauga  Alabama  01001    322              92            224
# 21           Autauga  Alabama  01001    239             133            205
# 22           Autauga  Alabama  01001    206              71            143
# 23           Autauga  Alabama  01001    222             150            190
# 24           Autauga  Alabama  01001    118              62             94
# ...              ...      ...    ...    ...             ...            ...
# 110519        Weston  Wyoming  56045     35               4             24
# 110520        Weston  Wyoming  56045     10               0              4
# 110521        Weston  Wyoming  56045     13               1              6
# 110522        Weston  Wyoming  56045      0               0              0
# 110523        Weston  Wyoming  56045     17               5             11
#
#         quantile_0.75  quantile_0.975
# 20                458            1132
# 21                287             404
# 22                291             499
# 23                261             347
# 24                146             209
# ...               ...             ...
# 110519             47              67
# 110520             17              27
# 110521             21              51
# 110522              0              14
# 110523             25              44
#
# [106044 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
