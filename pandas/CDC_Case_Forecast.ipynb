# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-10-04-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0         USC    2021-10-04  1 wk ahead inc case      2021-10-09
# 1     JHU-APL    2021-10-04  1 wk ahead inc case      2021-10-09
# 2    Columbia    2021-10-04  1 wk ahead inc case      2021-10-09
# 3  MIT-ISOLAT    2021-10-04  1 wk ahead inc case      2021-10-09
# 4     BPagano    2021-10-04  1 wk ahead inc case      2021-10-09
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   9456            7713           8842
# 1       Alabama  Alabama   01  10501            6133           8674
# 2       Alabama  Alabama   01  13298            9936          12149
# 3       Alabama  Alabama   01  10909               0           7154
# 4       Alabama  Alabama   01  11112            3775           8531
#
#    quantile_0.75  quantile_0.975
# 0          10248           11156
# 1          12635           17012
# 2          14597           17647
# 3          14663           21817
# 4          13579           18335

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#         model forecast_date               target target_end_date  \
# 0         USC    2021-10-04  1 wk ahead inc case      2021-10-09
# 1     JHU-APL    2021-10-04  1 wk ahead inc case      2021-10-09
# 2    Columbia    2021-10-04  1 wk ahead inc case      2021-10-09
# 3  MIT-ISOLAT    2021-10-04  1 wk ahead inc case      2021-10-09
# 4     BPagano    2021-10-04  1 wk ahead inc case      2021-10-09
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   9456            7713           8842
# 1       Alabama  Alabama   01  10501            6133           8674
# 2       Alabama  Alabama   01  13298            9936          12149
# 3       Alabama  Alabama   01  10909               0           7154
# 4       Alabama  Alabama   01  11112            3775           8531
#
#    quantile_0.75  quantile_0.975
# 0          10248           11156
# 1          12635           17012
# 2          14597           17647
# 3          14663           21817
# 4          13579           18335

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 19             Facebook    2021-10-04  1 wk ahead inc case      2021-10-09
# 20      PandemicCentral    2021-10-04  1 wk ahead inc case      2021-10-09
# 21             Columbia    2021-10-04  1 wk ahead inc case      2021-10-09
# 22                  UVA    2021-10-04  1 wk ahead inc case      2021-10-09
# 23             UGA-CEID    2021-10-04  1 wk ahead inc case      2021-10-09
# ...                 ...           ...                  ...             ...
# 122939         Facebook    2021-10-04  4 wk ahead inc case      2021-10-30
# 122940   JHU-UNC-Google    2021-10-04  4 wk ahead inc case      2021-10-30
# 122941  PandemicCentral    2021-10-04  4 wk ahead inc case      2021-10-30
# 122942          JHU-APL    2021-10-04  4 wk ahead inc case      2021-10-30
# 122943              UVA    2021-10-04  4 wk ahead inc case      2021-10-30
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 19           Autauga  Alabama  01001    114               0             62
# 20           Autauga  Alabama  01001    158              94            138
# 21           Autauga  Alabama  01001    102              33             77
# 22           Autauga  Alabama  01001    117              59             97
# 23           Autauga  Alabama  01001    127              83            112
# ...              ...      ...    ...    ...             ...            ...
# 122939        Weston  Wyoming  56045      8               0              0
# 122940        Weston  Wyoming  56045     14               0              0
# 122941        Weston  Wyoming  56045     26               7             16
# 122942        Weston  Wyoming  56045     13               4              8
# 122943        Weston  Wyoming  56045     27               8             20
#
#         quantile_0.75  quantile_0.975
# 19                167             267
# 20                169             242
# 21                127             183
# 22                137             175
# 23                141             190
# ...               ...             ...
# 122939             23              51
# 122940             29              87
# 122941             32              57
# 122942             18              32
# 122943             34              46
#
# [118676 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
