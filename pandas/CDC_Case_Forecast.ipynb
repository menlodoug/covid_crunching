# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-05-31-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                 model forecast_date               target target_end_date  \
# 0          MIT-ISOLAT    2021-05-31  1 wk ahead inc case      2021-06-05
# 1            Ensemble    2021-05-31  1 wk ahead inc case      2021-06-05
# 2  Masaryk University    2021-05-31  1 wk ahead inc case      2021-06-05
# 3                LANL    2021-05-31  1 wk ahead inc case      2021-06-05
# 4             MIT-ORC    2021-05-31  1 wk ahead inc case      2021-06-05
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   2931            1082           2294
# 1       Alabama  Alabama   01   1602             459           1103
# 2       Alabama  Alabama   01    442              37            272
# 3       Alabama  Alabama   01   1406              55            569
# 4       Alabama  Alabama   01    319               0              0
#
#    quantile_0.75  quantile_0.975
# 0           3567            4779
# 1           2272            3538
# 2            678            1394
# 3           2868            8163
# 4            720            1484

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#                 model forecast_date               target target_end_date  \
# 0          MIT-ISOLAT    2021-05-31  1 wk ahead inc case      2021-06-05
# 1            Ensemble    2021-05-31  1 wk ahead inc case      2021-06-05
# 2  Masaryk University    2021-05-31  1 wk ahead inc case      2021-06-05
# 3                LANL    2021-05-31  1 wk ahead inc case      2021-06-05
# 4             MIT-ORC    2021-05-31  1 wk ahead inc case      2021-06-05
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   2931            1082           2294
# 1       Alabama  Alabama   01   1602             459           1103
# 2       Alabama  Alabama   01    442              37            272
# 3       Alabama  Alabama   01   1406              55            569
# 4       Alabama  Alabama   01    319               0              0
#
#    quantile_0.75  quantile_0.975
# 0           3567            4779
# 1           2272            3538
# 2            678            1394
# 3           2868            8163
# 4            720            1484

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 24            Ensemble    2021-05-31  1 wk ahead inc case      2021-06-05
# 25        FRBSF-Wilson    2021-05-31  1 wk ahead inc case      2021-06-05
# 26            UGA-CEID    2021-05-31  1 wk ahead inc case      2021-06-05
# 27      JHU-UNC-Google    2021-05-31  1 wk ahead inc case      2021-06-05
# 28                 UVA    2021-05-31  1 wk ahead inc case      2021-06-05
# ...                ...           ...                  ...             ...
# 137459        Facebook    2021-05-31  4 wk ahead inc case      2021-06-26
# 137460        Columbia    2021-05-31  4 wk ahead inc case      2021-06-26
# 137461            LANL    2021-05-31  4 wk ahead inc case      2021-06-26
# 137462             UVA    2021-05-31  4 wk ahead inc case      2021-06-26
# 137463  JHU-UNC-Google    2021-05-31  4 wk ahead inc case      2021-06-26
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 24           Autauga  Alabama  01001     71               0             35
# 25           Autauga  Alabama  01001     71              37             59
# 26           Autauga  Alabama  01001     35               0              0
# 27           Autauga  Alabama  01001     68               0             35
# 28           Autauga  Alabama  01001    100               0             45
# ...              ...      ...    ...    ...             ...            ...
# 137459        Weston  Wyoming  56045      1               0              0
# 137460        Weston  Wyoming  56045      0               0              0
# 137461        Weston  Wyoming  56045      1               0              0
# 137462        Weston  Wyoming  56045      2               1              2
# 137463        Weston  Wyoming  56045      0               0              0
#
#         quantile_0.75  quantile_0.975
# 24                 86             165
# 25                 86             134
# 26                 69             195
# 27                125             196
# 28                156             261
# ...               ...             ...
# 137459              5              12
# 137460              0              14
# 137461              2               5
# 137462              3               3
# 137463              7              29
#
# [132056 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
