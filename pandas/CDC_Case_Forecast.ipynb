# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-09-06-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  JHU-APL    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 1      USC    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 2      UVA    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 3  MIT-ORC    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 4  Masaryk    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  38545           18920          30039          48904
# 1  Alabama   01  30061           25234          27979          32788
# 2  Alabama   01  30568           15023          25218          35917
# 3  Alabama   01  31608           17847          26872          36344
# 4  Alabama   01  60128           55558          58491          61970
#
#    quantile_0.975
# 0           72567
# 1           34809
# 2           46112
# 3           45369
# 4           68317

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  JHU-APL    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 1      USC    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 2      UVA    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 3  MIT-ORC    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
# 4  Masaryk    2021-09-06  1 wk ahead inc case      2021-09-11       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01  38545           18920          30039          48904
# 1  Alabama   01  30061           25234          27979          32788
# 2  Alabama   01  30568           15023          25218          35917
# 3  Alabama   01  31608           17847          26872          36344
# 4  Alabama   01  60128           55558          58491          61970
#
#    quantile_0.975
# 0           72567
# 1           34809
# 2           46112
# 3           45369
# 4           68317

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 21             UGA-CEID    2021-09-06  1 wk ahead inc case      2021-09-11
# 22             Columbia    2021-09-06  1 wk ahead inc case      2021-09-11
# 23                 LANL    2021-09-06  1 wk ahead inc case      2021-09-11
# 24             Ensemble    2021-09-06  1 wk ahead inc case      2021-09-11
# 25       JHU-UNC-Google    2021-09-06  1 wk ahead inc case      2021-09-11
# ...                 ...           ...                  ...             ...
# 128847  PandemicCentral    2021-09-06  4 wk ahead inc case      2021-10-02
# 128848          JHU-APL    2021-09-06  4 wk ahead inc case      2021-10-02
# 128849   JHU-UNC-Google    2021-09-06  4 wk ahead inc case      2021-10-02
# 128850         UGA-CEID    2021-09-06  4 wk ahead inc case      2021-10-02
# 128851         Columbia    2021-09-06  4 wk ahead inc case      2021-10-02
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 21           Autauga  Alabama  01001    331             171            275
# 22           Autauga  Alabama  01001    199             106            166
# 23           Autauga  Alabama  01001    233              83            165
# 24           Autauga  Alabama  01001    322             171            271
# 25           Autauga  Alabama  01001    337              11            265
# ...              ...      ...    ...    ...             ...            ...
# 128847        Weston  Wyoming  56045     36               6             25
# 128848        Weston  Wyoming  56045     29               7             18
# 128849        Weston  Wyoming  56045     35               0             11
# 128850        Weston  Wyoming  56045     29               0             15
# 128851        Weston  Wyoming  56045      0               0              0
#
#         quantile_0.75  quantile_0.975
# 21                379             557
# 22                235             301
# 23                321             558
# 24                346             546
# 25                488            9359
# ...               ...             ...
# 128847             45              67
# 128848             43              78
# 128849             97             223
# 128850             43              63
# 128851              0              14
#
# [124124 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
