# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-07-19-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  JHU-APL    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 1  BPagano    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 2      IEM    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 3      UVA    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 4   Karlen    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   4770            1797           3127           6698
# 1  Alabama   01  13151               0           8312          17779
# 2  Alabama   01   6537            3999           5611           7546
# 3  Alabama   01   6758             802           4708           8808
# 4  Alabama   01   5863            3153           4527           6559
#
#    quantile_0.975
# 0           10268
# 1           26697
# 2            9930
# 3           12714
# 4            9413

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#      model forecast_date               target target_end_date location_name  \
# 0  JHU-APL    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 1  BPagano    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 2      IEM    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 3      UVA    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
# 4   Karlen    2021-07-19  1 wk ahead inc case      2021-07-24       Alabama
#
#      State fips  point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  Alabama   01   4770            1797           3127           6698
# 1  Alabama   01  13151               0           8312          17779
# 2  Alabama   01   6537            3999           5611           7546
# 3  Alabama   01   6758             802           4708           8808
# 4  Alabama   01   5863            3153           4527           6559
#
#    quantile_0.975
# 0           10268
# 1           26697
# 2            9930
# 3           12714
# 4            9413

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                   model forecast_date               target target_end_date  \
# 20                  UVA    2021-07-19  1 wk ahead inc case      2021-07-24
# 21      PandemicCentral    2021-07-19  1 wk ahead inc case      2021-07-24
# 22       JHU-UNC-Google    2021-07-19  1 wk ahead inc case      2021-07-24
# 23             UGA-CEID    2021-07-19  1 wk ahead inc case      2021-07-24
# 24         FRBSF-Wilson    2021-07-19  1 wk ahead inc case      2021-07-24
# ...                 ...           ...                  ...             ...
# 122571         UGA-CEID    2021-07-19  4 wk ahead inc case      2021-08-14
# 122572         Columbia    2021-07-19  4 wk ahead inc case      2021-08-14
# 122573   JHU-UNC-Google    2021-07-19  4 wk ahead inc case      2021-08-14
# 122574         Facebook    2021-07-19  4 wk ahead inc case      2021-08-14
# 122575  PandemicCentral    2021-07-19  4 wk ahead inc case      2021-08-14
#
#        location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 20           Autauga  Alabama  01001     50              28             42
# 21           Autauga  Alabama  01001     52               4             27
# 22           Autauga  Alabama  01001     34               5             20
# 23           Autauga  Alabama  01001     49              16             37
# 24           Autauga  Alabama  01001     17               6             13
# ...              ...      ...    ...    ...             ...            ...
# 122571        Weston  Wyoming  56045      1               0              0
# 122572        Weston  Wyoming  56045      0               0              0
# 122573        Weston  Wyoming  56045      0               0              0
# 122574        Weston  Wyoming  56045      5               0              0
# 122575        Weston  Wyoming  56045      1               0              0
#
#         quantile_0.75  quantile_0.975
# 20                 58              72
# 21                 61             178
# 22                 53              92
# 23                 59              95
# 24                 23              44
# ...               ...             ...
# 122571              6              14
# 122572              0              14
# 122573              0              14
# 122574             17              39
# 122575              2               6
#
# [118084 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
