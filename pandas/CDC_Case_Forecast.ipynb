# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.0f}'.format

# %%
case_forecast_df = pd.read_csv('2021-10-25-all-forecasted-cases-model-data.csv')
case_forecast_df.head(5)
# Out:
#            model forecast_date               target target_end_date  \
# 0  MIT-Cassandra    2021-10-25  1 wk ahead inc case      2021-10-30
# 1       Columbia    2021-10-25  1 wk ahead inc case      2021-10-30
# 2        Masaryk    2021-10-25  1 wk ahead inc case      2021-10-30
# 3     MIT-ISOLAT    2021-10-25  1 wk ahead inc case      2021-10-30
# 4        JHU-APL    2021-10-25  1 wk ahead inc case      2021-10-30
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   6172            1298           4494
# 1       Alabama  Alabama   01   5739            4265           5056
# 2       Alabama  Alabama   01   3610             835           2500
# 3       Alabama  Alabama   01   2314               0           1517
# 4       Alabama  Alabama   01   5012            2714           4057
#
#    quantile_0.75  quantile_0.975
# 0           7850           11047
# 1           6353            7773
# 2           4923            7989
# 3           3110            4628
# 4           6127            8559

# %%
case_forecast_df['location_name'] = case_forecast_df['location_name'].apply(lambda x: x.split(' County,')[0])
case_forecast_df = case_forecast_df.fillna(0)
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '5 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '6 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '7 wk ahead inc case')]
case_forecast_df = case_forecast_df[(case_forecast_df['target'] != '8 wk ahead inc case')]
case_forecast_df.head(5)
# Out:
#            model forecast_date               target target_end_date  \
# 0  MIT-Cassandra    2021-10-25  1 wk ahead inc case      2021-10-30
# 1       Columbia    2021-10-25  1 wk ahead inc case      2021-10-30
# 2        Masaryk    2021-10-25  1 wk ahead inc case      2021-10-30
# 3     MIT-ISOLAT    2021-10-25  1 wk ahead inc case      2021-10-30
# 4        JHU-APL    2021-10-25  1 wk ahead inc case      2021-10-30
#
#   location_name    State fips  point  quantile_0.025  quantile_0.25  \
# 0       Alabama  Alabama   01   6172            1298           4494
# 1       Alabama  Alabama   01   5739            4265           5056
# 2       Alabama  Alabama   01   3610             835           2500
# 3       Alabama  Alabama   01   2314               0           1517
# 4       Alabama  Alabama   01   5012            2714           4057
#
#    quantile_0.75  quantile_0.975
# 0           7850           11047
# 1           6353            7773
# 2           4923            7989
# 3           3110            4628
# 4           6127            8559

# %%
case_forecast_df = case_forecast_df.query("State != location_name")
case_forecast_df
# Out:
#                  model forecast_date               target target_end_date  \
# 16     PandemicCentral    2021-10-25  1 wk ahead inc case      2021-10-30
# 17        FRBSF-Wilson    2021-10-25  1 wk ahead inc case      2021-10-30
# 18                 UVA    2021-10-25  1 wk ahead inc case      2021-10-30
# 19            Facebook    2021-10-25  1 wk ahead inc case      2021-10-30
# 20            Columbia    2021-10-25  1 wk ahead inc case      2021-10-30
# ...                ...           ...                  ...             ...
# 97423              UVA    2021-10-25  4 wk ahead inc case      2021-11-20
# 97424        CUBoulder    2021-10-25  4 wk ahead inc case      2021-11-20
# 97425         Facebook    2021-10-25  4 wk ahead inc case      2021-11-20
# 97426  PandemicCentral    2021-10-25  4 wk ahead inc case      2021-11-20
# 97427         Columbia    2021-10-25  4 wk ahead inc case      2021-11-20
#
#       location_name    State   fips  point  quantile_0.025  quantile_0.25  \
# 16          Autauga  Alabama  01001     77               0             44
# 17          Autauga  Alabama  01001     39              16             30
# 18          Autauga  Alabama  01001     85               0             49
# 19          Autauga  Alabama  01001     68               0             27
# 20          Autauga  Alabama  01001     57              12             40
# ...             ...      ...    ...    ...             ...            ...
# 97423        Weston  Wyoming  56045     41               0             23
# 97424        Weston  Wyoming  56045     23               3             14
# 97425        Weston  Wyoming  56045     12               0              0
# 97426        Weston  Wyoming  56045     34              17             22
# 97427        Weston  Wyoming  56045      0               0              0
#
#        quantile_0.75  quantile_0.975
# 16                83             284
# 17                50              93
# 18               120             187
# 19               108             185
# 20                77             118
# ...              ...             ...
# 97423             58              91
# 97424             31              60
# 97425             31              65
# 97426             37              87
# 97427              1              14
#
# [93840 rows x 12 columns]

# %%
case_forecast_df.to_csv('case_forecast.csv', index=False)
