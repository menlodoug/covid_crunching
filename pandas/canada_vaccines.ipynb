# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
canada_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/Canada.csv')
canada_shot.tail()
# Out:
#     location        date                                       vaccine  \
# 162   Canada  2021-05-25  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 163   Canada  2021-05-26  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 164   Canada  2021-05-27  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 165   Canada  2021-05-28  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 166   Canada  2021-05-29  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                             source_url  total_vaccinations  \
# 162  https://covid19tracker.ca/vaccinationtracker.html            21637723
# 163  https://covid19tracker.ca/vaccinationtracker.html            21939046
# 164  https://covid19tracker.ca/vaccinationtracker.html            22347313
# 165  https://covid19tracker.ca/vaccinationtracker.html            22810709
# 166  https://covid19tracker.ca/vaccinationtracker.html            23157029
#
#      people_vaccinated  people_fully_vaccinated
# ...

# %%
canada_vac = canada_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
canada_vac.rename(columns={'location' : 'country'}, inplace=True)
canada_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            date  total_vaccinations  people_vaccinated  \
# 162  2021-05-25            21637723           19942129
# 163  2021-05-26            21939046           20195328
# 164  2021-05-27            22347313           20539206
# 165  2021-05-28            22810709           20932071
# 166  2021-05-29            23157029           21207890
#
#      people_fully_vaccinated country
# 162                  1695594  Canada
# 163                  1743718  Canada
# 164                  1808107  Canada
# 165                  1878638  Canada
# 166                  1949139  Canada

# %%
canada_vac.to_csv('canada_shot.csv', index=False)
