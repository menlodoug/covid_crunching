# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
canada_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/Canada.csv')
canada_shot.tail()
# Out:
#     location        date                                       vaccine  \
# 147   Canada  2021-05-10  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 148   Canada  2021-05-11  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 149   Canada  2021-05-12  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 150   Canada  2021-05-13  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 151   Canada  2021-05-14  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                             source_url  total_vaccinations  \
# 147  https://covid19tracker.ca/vaccinationtracker.html            16258155
# 148  https://covid19tracker.ca/vaccinationtracker.html            16557932
# 149  https://covid19tracker.ca/vaccinationtracker.html            16904709
# 150  https://covid19tracker.ca/vaccinationtracker.html            17297879
# 151  https://covid19tracker.ca/vaccinationtracker.html            17734322
#
#      people_vaccinated  people_fully_vaccinated
# 147           14991030                  1267125
# 148           15272541                  1285391
# 149           15596419                  1308290
# 150           15961692                  1336187
# 151           16363943                  1370379

# %%
canada_vac = canada_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
canada_vac.rename(columns={'location' : 'country'}, inplace=True)
canada_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            date  total_vaccinations  people_vaccinated  \
# 147  2021-05-10            16258155           14991030
# 148  2021-05-11            16557932           15272541
# 149  2021-05-12            16904709           15596419
# 150  2021-05-13            17297879           15961692
# 151  2021-05-14            17734322           16363943
#
#      people_fully_vaccinated country
# 147                  1267125  Canada
# 148                  1285391  Canada
# 149                  1308290  Canada
# 150                  1336187  Canada
# 151                  1370379  Canada

# %%
canada_vac.to_csv('canada_shot.csv', index=False)
