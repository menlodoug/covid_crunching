# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
positive_df = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-positive-test-rate.csv')
positive_df.tail(5)
# Out:
#            date  confirmed_cases  total_tests  new_confirmed_cases  \
# 910  2022-07-30       9992840.00 179742855.00              8266.00
# 911  2022-07-31       9999458.00 179790161.00              6618.00
# 912  2022-08-01      10013528.00 179918534.00             14070.00
# 913  2022-08-02      10022099.00 179990076.00              8571.00
# 914  2022-08-03      10023807.00 180003735.00              1708.00
#
#      new_positive_tests  new_tests  new_confirmed_cases_seven_day_total  \
# 910            11141.00   58269.00                            127123.00
# 911             8869.00   47306.00                            124970.00
# 912            16324.00  128373.00                            114771.00
# 913             8910.00   71542.00                            100788.00
# 914             1869.00   13659.00                             82026.00
#
#      new_tests_seven_day_total  positive_test_rate_seven_day_percent
# 910                  860791.00                                  0.15
# 911                  852944.00                                  0.15
# 912                  798736.00                                  0.14
# 913                  704557.00                                  0.14
# 914                  569947.00                                  0.14

# %%
bool_series = pd.notnull(positive_df["new_tests_seven_day_total"])
positivity = positive_df[bool_series]
positivity['test'] = 'COVID'
positivity[['confirmed_cases','total_tests','new_confirmed_cases', 'new_positive_tests','new_tests','new_confirmed_cases_seven_day_total','new_tests_seven_day_total']] = positivity[['confirmed_cases','total_tests','new_confirmed_cases', 'new_positive_tests','new_tests','new_confirmed_cases_seven_day_total','new_tests_seven_day_total']].astype(int)
positivity
# Out:
# <ipython-input-3-c4ca47601257>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positivity['test'] = 'COVID'
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#            date  confirmed_cases  total_tests  new_confirmed_cases  \
# 6    2020-02-07               83          911                   32
# 7    2020-02-08               90          970                    7
# 8    2020-02-09               96          991                    6
# 9    2020-02-10              102         1007                    6
# 10   2020-02-11              106         1047                    4
# ..          ...              ...          ...                  ...
# 910  2022-07-30          9992840    179742855                 8266
# 911  2022-07-31          9999458    179790161                 6618
# 912  2022-08-01         10013528    179918534                14070
# 913  2022-08-02         10022099    179990076                 8571
# 914  2022-08-03         10023807    180003735                 1708
#
#      new_positive_tests  new_tests  new_confirmed_cases_seven_day_total  \
# 6                    62        453                                   77
# 7                     2         59                                   70
# 8                     1         21                                   69
# 9                     1         16                                   69
# 10                    0         40                                   68
# ..                  ...        ...                                  ...
# 910               11141      58269                               127123
# 911                8869      47306                               124970
# 912               16324     128373                               114771
# 913                8910      71542                               100788
# 914                1869      13659                                82026
#
#      new_tests_seven_day_total  positive_test_rate_seven_day_percent   test
# 6                          911                                  0.08  COVID
# 7                          666                                  0.11  COVID
# 8                          651                                  0.11  COVID
# 9                          638                                  0.11  COVID
# 10                         646                                  0.11  COVID
# ..                         ...                                   ...    ...
# 910                     860791                                  0.15  COVID
# 911                     852944                                  0.15  COVID
# 912                     798736                                  0.14  COVID
# 913                     704557                                  0.14  COVID
# 914                     569947                                  0.14  COVID
#
# [909 rows x 10 columns]

# %%
positivity.to_csv('positivity.csv', index=False)
