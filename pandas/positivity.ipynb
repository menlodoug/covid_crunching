# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
positive_df = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-positive-test-rate.csv')
positive_df.tail(5)
# Out:
#            date  confirmed_cases  total_tests  new_confirmed_cases  new_tests  \
# 388  2021-02-17          3416147  46384932.00              4090.00  157207.00
# 389  2021-02-18          3421720  46504255.00              5573.00  119323.00
# 390  2021-02-19          3428518  46621654.00              6798.00  117399.00
# 391  2021-02-20          3435186  46813876.00              6668.00  192222.00
# 392  2021-02-21          3441946  47043348.00              6760.00  229472.00
#
#      new_confirmed_cases_seven_day_total  new_tests_seven_day_total  \
# 388                             53166.00                 1614331.00
# 389                             50164.00                 1580274.00
# 390                             46903.00                 1496213.00
# 391                             44150.00                 1402239.00
# 392                             42068.00                 1340131.00
#
#      positive_test_rate_seven_day_percent
# 388                                  0.03
# 389                                  0.03
# 390                                  0.03
# 391                                  0.03
# 392                                  0.03

# %%
bool_series = pd.notnull(positive_df["new_tests_seven_day_total"])
positivity = positive_df[bool_series]
positivity['test'] = 'COVID'
positivity
# Out:
# <ipython-input-3-dd681627605a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positivity['test'] = 'COVID'
#            date  confirmed_cases  total_tests  new_confirmed_cases  new_tests  \
# 61   2020-03-26             3006     77800.00               471.00   11000.00
# 62   2020-03-27             3801     88400.00               795.00   10600.00
# 63   2020-03-28             4643     89600.00               842.00    1200.00
# 64   2020-03-30             5763     83800.00              1120.00   -5800.00
# 65   2020-03-31             6932     86100.00              1169.00    2300.00
# ..          ...              ...          ...                  ...        ...
# 388  2021-02-17          3416147  46384932.00              4090.00  157207.00
# 389  2021-02-18          3421720  46504255.00              5573.00  119323.00
# 390  2021-02-19          3428518  46621654.00              6798.00  117399.00
# 391  2021-02-20          3435186  46813876.00              6668.00  192222.00
# 392  2021-02-21          3441946  47043348.00              6760.00  229472.00
#
#      new_confirmed_cases_seven_day_total  new_tests_seven_day_total  \
# 61                               2331.00                   60900.00
# 62                               2795.00                   65200.00
# 63                               3419.00                   64400.00
# 64                               4295.00                   57600.00
# 65                               5199.00                   59700.00
# ..                                   ...                        ...
# 388                             53166.00                 1614331.00
# 389                             50164.00                 1580274.00
# 390                             46903.00                 1496213.00
# 391                             44150.00                 1402239.00
# 392                             42068.00                 1340131.00
#
#      positive_test_rate_seven_day_percent   test
# 61                                   0.04  COVID
# 62                                   0.04  COVID
# 63                                   0.05  COVID
# 64                                   0.07  COVID
# 65                                   0.09  COVID
# ..                                    ...    ...
# 388                                  0.03  COVID
# 389                                  0.03  COVID
# 390                                  0.03  COVID
# 391                                  0.03  COVID
# 392                                  0.03  COVID
#
# [332 rows x 9 columns]

# %%
positivity.to_csv('positivity.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-4-4c6f2f0d70be> in <module>
# ----> 1 positivity.to_csv('positivity.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'positivity.csv'
