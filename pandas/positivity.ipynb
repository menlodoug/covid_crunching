# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
positive_df = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-positive-test-rate.csv')
positive_df.tail(5)
# Out:
#            date  confirmed_cases  total_tests  new_confirmed_cases  \
# 628  2021-10-21       4606125.00 100610474.00                 0.00
# 629  2021-10-22              nan 100704534.00                  nan
# 630  2021-10-23              nan 100713010.00                  nan
# 631  2021-10-24              nan          nan                  nan
# 632         NaN              nan          nan               474.00
#
#      new_positive_tests  new_tests  new_confirmed_cases_seven_day_total  \
# 628             5764.00  284746.00                             41989.00
# 629             2870.00   94060.00                             38195.00
# 630              462.00    8476.00                             34843.00
# 631                 nan        nan                                  nan
# 632             3109.00   55547.00                                  nan
#
#      new_tests_seven_day_total  positive_test_rate_seven_day_percent
# 628                 2010993.00                                  0.02
# 629                 1768980.00                                  0.02
# 630                 1676426.00                                  0.02
# 631                        nan                                   nan
# 632                        nan                                   nan

# %%
bool_series = pd.notnull(positive_df["new_tests_seven_day_total"])
positivity = positive_df[bool_series]
positivity['test'] = 'COVID'
positivity
# Out:
# <ipython-input-3-dd681627605a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positivity['test'] = 'COVID'
#            date  confirmed_cases  total_tests  new_confirmed_cases  \
# 6    2020-02-07            83.00       902.00                33.00
# 7    2020-02-08            90.00       959.00                 7.00
# 8    2020-02-09            96.00       980.00                 6.00
# 9    2020-02-10           104.00       996.00                 8.00
# 10   2020-02-11           108.00      1036.00                 4.00
# ..          ...              ...          ...                  ...
# 626  2021-10-19       4605545.00  99946272.00              2575.00
# 627  2021-10-20       4606125.00 100325728.00               580.00
# 628  2021-10-21       4606125.00 100610474.00                 0.00
# 629  2021-10-22              nan 100704534.00                  nan
# 630  2021-10-23              nan 100713010.00                  nan
#
#      new_positive_tests  new_tests  new_confirmed_cases_seven_day_total  \
# 6                 62.00     452.00                                77.00
# 7                  1.00      57.00                                69.00
# 8                  1.00      21.00                                68.00
# 9                  1.00      16.00                                68.00
# 10                 0.00      40.00                                67.00
# ..                  ...        ...                                  ...
# 626             7414.00  393816.00                             43107.00
# 627             6810.00  379456.00                             42903.00
# 628             5764.00  284746.00                             41989.00
# 629             2870.00   94060.00                             38195.00
# 630              462.00    8476.00                             34843.00
#
#      new_tests_seven_day_total  positive_test_rate_seven_day_percent   test
# 6                       902.00                                  0.09  COVID
# 7                       658.00                                  0.10  COVID
# 8                       645.00                                  0.11  COVID
# 9                       632.00                                  0.11  COVID
# 10                      641.00                                  0.10  COVID
# ..                         ...                                   ...    ...
# 626                 2138235.00                                  0.02  COVID
# 627                 2116076.00                                  0.02  COVID
# 628                 2010993.00                                  0.02  COVID
# 629                 1768980.00                                  0.02  COVID
# 630                 1676426.00                                  0.02  COVID
#
# [625 rows x 10 columns]

# %%
positivity.to_csv('positivity.csv', index=False)
