# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.3f}'.format

# %%
shots_df = pd.read_csv('covid19_vaccinations.csv')
shots_df
# Out:
#    State/Territory/Federal Entity  Total Doses Distributed  \
# 0                          Alaska                  1769065
# 1                         Alabama                 10759340
# 2                        Arkansas                  7044280
# 3                         Arizona                 16642720
# 4                      California                101104185
# 5                        Colorado                 14231075
# 6                     Connecticut                  9899825
# 7            District of Columbia                  2175205
# 8                        Delaware                  2694155
# 9                         Florida                 53187085
# 10                        Georgia                 24461555
# 11                         Hawaii                  3864180
# 12                           Iowa                  7592555
# 13                          Idaho                  3921690
# 14                       Illinois                 30964975
# ...

# %%
shots_df['Pop'] = shots_df['Total Doses Distributed']/(shots_df['Doses Distributed per 100K']/100000)
shots_df.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Distributed  \
# 0                         Alaska                  1769065
# 1                        Alabama                 10759340
# 2                       Arkansas                  7044280
# 3                        Arizona                 16642720
# 4                     California                101104185
#
#    Doses Distributed per 100K  18+ Doses Distributed per 100K  \
# 0                      241826                          320737
# 1                      219436                          282036
# 2                      233424                          303941
# 3                      228649                          295163
# 4                      255881                          330216
#
#    Total Doses Administered by State where Administered  \
# 0                                            1204887
# 1                                            6566505
# 2                                            4467033
# ...

# %%
booster_df = shots_df[['State/Territory/Federal Entity', 'Total Doses Distributed', 'Doses Distributed per 100K', 'People with a first booster dose','Percent of fully vaccinated people with a first booster dose' ,'Pop', 'Date' ]]
booster_df.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Distributed  \
# 0                         Alaska                  1769065
# 1                        Alabama                 10759340
# 2                       Arkansas                  7044280
# 3                        Arizona                 16642720
# 4                     California                101104185
#
#    Doses Distributed per 100K  People with a first booster dose  \
# 0                      241826                            218463
# 1                      219436                            970025
# 2                      233424                            706277
# 3                      228649                           2074232
# 4                      255881                          16219949
#
#    Percent of fully vaccinated people with a first booster dose          Pop  \
# 0                                             47.100              731544.582
# ...

# %%
#booster_df['Booster Percent'] = booster_df['People with a first booster dose']/(booster_df['Pop'])
booster_df.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Distributed  \
# 0                         Alaska                  1769065
# 1                        Alabama                 10759340
# 2                       Arkansas                  7044280
# 3                        Arizona                 16642720
# 4                     California                101104185
#
#    Doses Distributed per 100K  People with a first booster dose  \
# 0                      241826                            218463
# 1                      219436                            970025
# 2                      233424                            706277
# 3                      228649                           2074232
# 4                      255881                          16219949
#
#    Percent of fully vaccinated people with a first booster dose          Pop  \
# 0                                             47.100              731544.582
# ...

# %%
booster_df = booster_df.rename(columns = {'State/Territory/Federal Entity' : 'State', 'Total Doses Distributed' : 'Total Doses', 'Doses Distributed per 100K' : 'Doses per 100K', 'People who have received a booster dose' : 'Booster Doses'})
booster_df.head()
# Out:
#         State  Total Doses  Doses per 100K  People with a first booster dose  \
# 0      Alaska      1769065          241826                            218463
# 1     Alabama     10759340          219436                            970025
# 2    Arkansas      7044280          233424                            706277
# 3     Arizona     16642720          228649                           2074232
# 4  California    101104185          255881                          16219949
#
#    Percent of fully vaccinated people with a first booster dose          Pop  \
# 0                                             47.100              731544.582
# 1                                             37.900             4903179.059
# 2                                             42.100             3017804.510
# 3                                             45.100             7278719.784
# 4                                             55.800            39512189.260
#
#         Date
# 0  9/14/2022
# ...

# %%
# Export updated national data to csv for use in Tableau

booster_df.to_csv('booster.csv', index=False)
