# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.3f}'.format

# %%
shots_df = pd.read_csv('covid19_vaccinations.csv')
shots_df
# Out:
#    State/Territory/Federal Entity  Total Doses Delivered  \
# 0                          Alaska                1482265
# 1                         Alabama                9396740
# 2                        Arkansas                5952680
# 3                         Arizona               14312020
# 4                      California               87229285
# 5                        Colorado               12046675
# 6                     Connecticut                8439225
# 7            District of Columbia                1806005
# 8                        Delaware                2264955
# 9                         Florida               46351885
# 10                        Georgia               21002095
# 11                         Hawaii                3350880
# 12                           Iowa                6347955
# 13                          Idaho                3273690
# 14                       Illinois               26536245
# ...

# %%
shots_df['Pop'] = shots_df['Total Doses Delivered']/(shots_df['Doses Delivered per 100K']/100000)
shots_df.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Delivered  \
# 0                         Alaska                1482265
# 1                        Alabama                9396740
# 2                       Arkansas                5952680
# 3                        Arizona               14312020
# 4                     California               87229285
#
#    Doses Delivered per 100K  18+ Doses Delivered per 100K  \
# 0                    202621                        268740
# 1                    191646                        246318
# 2                    197252                        256841
# 3                    196628                        253828
# 4                    220765                        284899
#
#    Total Doses Administered by State where Administered  \
# 0                                            1113386
# 1                                            6154128
# 2                                            4131074
# 3                                           11746475
# ...

# %%
booster_df = shots_df[['State/Territory/Federal Entity', 'Total Doses Delivered', 'Doses Delivered per 100K', 'People who have received a booster dose', 'Pop', 'Date' ]]
booster_df.head()
# Out:
#   State/Territory/Federal Entity  Total Doses Delivered  \
# 0                         Alaska                1482265
# 1                        Alabama                9396740
# 2                       Arkansas                5952680
# 3                        Arizona               14312020
# 4                     California               87229285
#
#    Doses Delivered per 100K  People who have received a booster dose  \
# 0                    202621                                   190024
# 1                    191646                                   864594
# 2                    197252                                   627762
# 3                    196628                                  1797292
# 4                    220765                                 13890035
#
#            Pop       Date
# 0   731545.595  3/27/2022
# 1  4903175.647  3/27/2022
# 2  3017804.636  3/27/2022
# 3  7278729.377  3/27/2022
# 4 39512280.026  3/27/2022

# %%
booster_df['Booster Percent'] = booster_df['People who have received a booster dose']/(booster_df['Pop'])
booster_df.head()
# Out:
# <ipython-input-5-b5e0594bff54>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   booster_df['Booster Percent'] = booster_df['People who have received a booster dose']/(booster_df['Pop'])
#   State/Territory/Federal Entity  Total Doses Delivered  \
# 0                         Alaska                1482265
# 1                        Alabama                9396740
# 2                       Arkansas                5952680
# 3                        Arizona               14312020
# 4                     California               87229285
#
#    Doses Delivered per 100K  People who have received a booster dose  \
# 0                    202621                                   190024
# ...

# %%
booster_df = booster_df.rename(columns = {'State/Territory/Federal Entity' : 'State', 'Total Doses Delivered' : 'Total Doses', 'Doses Delivered per 100K' : 'Doses per 100K', 'People who have received a booster dose' : 'Booster Doses'})
booster_df.head()
# Out:
#         State  Total Doses  Doses per 100K  Booster Doses          Pop  \
# 0      Alaska      1482265          202621         190024   731545.595
# 1     Alabama      9396740          191646         864594  4903175.647
# 2    Arkansas      5952680          197252         627762  3017804.636
# 3     Arizona     14312020          196628        1797292  7278729.377
# 4  California     87229285          220765       13890035 39512280.026
#
#         Date  Booster Percent
# 0  3/27/2022            0.260
# 1  3/27/2022            0.176
# 2  3/27/2022            0.208
# 3  3/27/2022            0.247
# 4  3/27/2022            0.352

# %%
# Export updated national data to csv for use in Tableau

booster_df.to_csv('booster.csv', index=False)
