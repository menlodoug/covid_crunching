# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
jail_df = pd.read_csv("https://raw.githubusercontent.com/uclalawcovid19behindbars/data/master/latest-data/latest_facility_counts.csv", low_memory=False)
jail_df = jail_df[['Facility.ID', 'Jurisdiction', 'State', 'Name', 'Address', 'City', 'Zipcode', 'County', 'County.FIPS', 'Latitude', 'Longitude','Residents.Confirmed', 'Staff.Confirmed', 'Residents.Deaths', 'Staff.Deaths', 'Date']].fillna(0)
jail_df['Date'] = pd.to_datetime(jail_df['Date'])
jail_df['Address'] = jail_df['Address'].str.title()
jail_df['City'] = jail_df['City'].str.title()
jail_df['County'] = jail_df['County'].str.title()
jail_df[['Facility.ID','Zipcode', 'County.FIPS', 'Staff.Confirmed', 'Residents.Deaths', 'Staff.Deaths']] = jail_df[['Facility.ID', 'Zipcode','County.FIPS', 'Staff.Confirmed', 'Residents.Deaths', 'Staff.Deaths']].astype(int)
jail_df
# Out:
#       Facility.ID Jurisdiction          State  \
# 0               1        state        Alabama
# 1               2        state        Alabama
# 2               3        state        Alabama
# 3               5        state        Alabama
# 4               6        state        Alabama
# ...           ...          ...            ...
# 1751         2728        state        Vermont
# 1752         2729        state  West Virginia
# 1753         2730  immigration        Arizona
# 1754         2733  immigration     California
# 1755         2736       county          Texas
#
#                                           Name                 Address  \
# 0                         ALABAMA HEADQUARTERS                     NaN
# 1     ALABAMA TREATMENT AND EDUCATION FACILITY  102 Industrial Parkway
# 2           ALEX CITY COMMUNITY BASED FACILITY         Highway 22 West
# 3                   BIBB CORRECTIONAL FACILITY           565 Bibb Lane
# 4          BIRMINGHAM COMMUNITY BASED FACILITY          1216 25Th St N
# ...                                        ...                     ...
# 1751   SPRINGFIELD PROBATION AND PAROLE OFFICE                     NaN
# 1752                  NON-FACILITY STAFF TOTAL                     NaN
# 1753    ICE WINGATE BY WYNDHAM - HOUSE OF HOPE      1760 S Sunridge Dr
# 1754                     ICE DESERT VIEW ANNEX         10450 Rancho Rd
# 1755                        HOWARD COUNTY JAIL          3611 W. Hwy 80
#
#             City  Zipcode     County  County.FIPS  Latitude  Longitude  \
# 0            NaN        0        NaN            0      0.00       0.00
# 1     Columbiana    35051     Shelby         1117     33.18     -86.62
# 2      Alex City    35011      Coosa         1037     32.90     -86.01
# 3          Brent    35034       Bibb         1007     32.92     -87.16
# 4     Birmingham    35234  Jefferson         1073     33.53     -86.81
# ...          ...      ...        ...          ...       ...        ...
# 1751         NaN        0        NaN            0     44.06     -72.67
# 1752         NaN        0        NaN            0     37.55     -80.54
# 1753        Yuma    85365       Yuma         4027     32.70    -114.60
# 1754    Adelanto    92301        NaN            0     34.56    -117.44
# 1755  Big Spring    79720     Howard        48227     32.23    -101.51
#
#       Residents.Confirmed  Staff.Confirmed  Residents.Deaths  Staff.Deaths  \
# 0                    0.00               86                 0             0
# 1                   11.00                2                 1             0
# 2                   78.00               19                 0             0
# 3                  164.00               62                 3             0
# 4                   17.00               30                 0             0
# ...                   ...              ...               ...           ...
# 1751                 0.00                1                 0             0
# 1752                 0.00               48                 0             0
# 1753               145.00                0                 0             0
# 1754                19.00                0                 0             0
# 1755                 0.00                0                 1             0
#
#            Date
# 0    2021-09-21
# 1    2021-09-21
# 2    2021-09-21
# 3    2021-09-21
# 4    2021-09-21
# ...         ...
# 1751 2021-09-21
# 1752 2021-09-21
# 1753 2021-08-31
# 1754 2021-09-21
# 1755 2021-09-21
#
# [1756 rows x 16 columns]

# %%
jailed = jail_df
jailed2 = jailed[(jailed['Facility.ID'] != 0)]
jailed2 = jailed2.sort_values(by=['Facility.ID'])
jailed2.to_csv('jailed2.csv', index=False)

# %%
#jail_df.to_csv('jail.csv', index=False)
jail = jail_df[(jail_df['Facility.ID'] == 0)]
jail.rename({'Facility.ID': 'ID'}, axis=1, inplace=True)
jail
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# Empty DataFrame
# Columns: [ID, Jurisdiction, State, Name, Address, City, Zipcode, County, County.FIPS, Latitude, Longitude, Residents.Confirmed, Staff.Confirmed, Residents.Deaths, Staff.Deaths, Date]
# Index: []

# %%
jail.to_csv('no_id.csv', index=False)

# %%
summed = jailed2.groupby(['Facility.ID', 'Date']).sum()
listed = summed.reset_index(drop=False)
listed.rename({'Facility.ID': 'ID'}, axis=1, inplace=True)
listed
# Out:
#         ID       Date  Zipcode  County.FIPS  Latitude  Longitude  \
# 0        1 2021-09-21        0            0      0.00       0.00
# 1        2 2021-09-21    35051         1117     33.18     -86.62
# 2        3 2021-09-21    35011         1037     32.90     -86.01
# 3        5 2021-09-21    35034         1007     32.92     -87.16
# 4        6 2021-09-21    35234         1073     33.53     -86.81
# ...    ...        ...      ...          ...       ...        ...
# 1751  2728 2021-09-21        0            0     44.06     -72.67
# 1752  2729 2021-09-21        0            0     37.55     -80.54
# 1753  2730 2021-08-31    85365         4027     32.70    -114.60
# 1754  2733 2021-09-21    92301            0     34.56    -117.44
# 1755  2736 2021-09-21    79720        48227     32.23    -101.51
#
#       Residents.Confirmed  Staff.Confirmed  Residents.Deaths  Staff.Deaths
# 0                    0.00               86                 0             0
# 1                   11.00                2                 1             0
# 2                   78.00               19                 0             0
# 3                  164.00               62                 3             0
# 4                   17.00               30                 0             0
# ...                   ...              ...               ...           ...
# 1751                 0.00                1                 0             0
# 1752                 0.00               48                 0             0
# 1753               145.00                0                 0             0
# 1754                19.00                0                 0             0
# 1755                 0.00                0                 1             0
#
# [1756 rows x 10 columns]

# %%
listed.to_csv('jailed.csv', index=False)

# %%
jailed2
# Out:
#       Facility.ID Jurisdiction          State  \
# 0               1        state        Alabama
# 1               2        state        Alabama
# 2               3        state        Alabama
# 3               5        state        Alabama
# 4               6        state        Alabama
# ...           ...          ...            ...
# 1751         2728        state        Vermont
# 1752         2729        state  West Virginia
# 1753         2730  immigration        Arizona
# 1754         2733  immigration     California
# 1755         2736       county          Texas
#
#                                           Name                 Address  \
# 0                         ALABAMA HEADQUARTERS                     NaN
# 1     ALABAMA TREATMENT AND EDUCATION FACILITY  102 Industrial Parkway
# 2           ALEX CITY COMMUNITY BASED FACILITY         Highway 22 West
# 3                   BIBB CORRECTIONAL FACILITY           565 Bibb Lane
# 4          BIRMINGHAM COMMUNITY BASED FACILITY          1216 25Th St N
# ...                                        ...                     ...
# 1751   SPRINGFIELD PROBATION AND PAROLE OFFICE                     NaN
# 1752                  NON-FACILITY STAFF TOTAL                     NaN
# 1753    ICE WINGATE BY WYNDHAM - HOUSE OF HOPE      1760 S Sunridge Dr
# 1754                     ICE DESERT VIEW ANNEX         10450 Rancho Rd
# 1755                        HOWARD COUNTY JAIL          3611 W. Hwy 80
#
#             City  Zipcode     County  County.FIPS  Latitude  Longitude  \
# 0            NaN        0        NaN            0      0.00       0.00
# 1     Columbiana    35051     Shelby         1117     33.18     -86.62
# 2      Alex City    35011      Coosa         1037     32.90     -86.01
# 3          Brent    35034       Bibb         1007     32.92     -87.16
# 4     Birmingham    35234  Jefferson         1073     33.53     -86.81
# ...          ...      ...        ...          ...       ...        ...
# 1751         NaN        0        NaN            0     44.06     -72.67
# 1752         NaN        0        NaN            0     37.55     -80.54
# 1753        Yuma    85365       Yuma         4027     32.70    -114.60
# 1754    Adelanto    92301        NaN            0     34.56    -117.44
# 1755  Big Spring    79720     Howard        48227     32.23    -101.51
#
#       Residents.Confirmed  Staff.Confirmed  Residents.Deaths  Staff.Deaths  \
# 0                    0.00               86                 0             0
# 1                   11.00                2                 1             0
# 2                   78.00               19                 0             0
# 3                  164.00               62                 3             0
# 4                   17.00               30                 0             0
# ...                   ...              ...               ...           ...
# 1751                 0.00                1                 0             0
# 1752                 0.00               48                 0             0
# 1753               145.00                0                 0             0
# 1754                19.00                0                 0             0
# 1755                 0.00                0                 1             0
#
#            Date
# 0    2021-09-21
# 1    2021-09-21
# 2    2021-09-21
# 3    2021-09-21
# 4    2021-09-21
# ...         ...
# 1751 2021-09-21
# 1752 2021-09-21
# 1753 2021-08-31
# 1754 2021-09-21
# 1755 2021-09-21
#
# [1756 rows x 16 columns]

# %%
jailed.to_csv('all.csv', index=False)
