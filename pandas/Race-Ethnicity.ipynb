# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
race_df = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-race-ethnicity.csv')
race_df
# Out:
#             date   race    age  confirmed_cases_total  \
# 0     2021-08-04  asian   0-17                  22067
# 1     2021-08-04  asian    18+                 212832
# 2     2021-08-04  asian  18-34                  72042
# 3     2021-08-04  asian  35-49                  51508
# 4     2021-08-04  asian  50-64                  49718
# ...          ...    ...    ...                    ...
# 9931  2020-05-14  white  35-49                   2392
# 9932  2020-05-14  white  50-64                   3062
# 9933  2020-05-14  white  65-79                   2433
# 9934  2020-05-14  white    80+                   1665
# 9935  2020-05-14  white    all                  11956
#
#       confirmed_cases_percent  deaths_total  deaths_percent  \
# 0                        0.05             4            0.13
# 1                        0.08          7949            0.13
# 2                        0.07            69            0.07
# 3                        0.07           212            0.06
# 4                        0.08          1099            0.09
# ...                       ...           ...             ...
# 9931                     0.18            11            0.08
# 9932                     0.24            96            0.22
# 9933                     0.36           312            0.34
# 9934                     0.44           569            0.42
# 9935                     0.23           991            0.34
#
#       population_percent
# 0                   0.13
# 1                   0.17
# 2                   0.15
# 3                   0.18
# 4                   0.17
# ...                  ...
# 9931                0.33
# 9932                0.43
# 9933                0.54
# 9934                0.57
# 9935                0.37
#
# [9936 rows x 8 columns]

# %%
race_df.replace(to_replace =["other", "cdph-other"], value ="Other", inplace=True)
race_df.replace(to_replace ="asian", value ="Asian", inplace=True)
race_df.replace(to_replace ="black", value ="Black", inplace=True)
race_df.replace(to_replace ="latino", value ="Latino", inplace=True)
race_df.replace(to_replace ="white", value ="White", inplace=True)
race_df.replace(to_replace ="all", value ="Total", inplace=True)
race_df
# Out:
#             date   race    age  confirmed_cases_total  \
# 0     2021-08-04  Asian   0-17                  22067
# 1     2021-08-04  Asian    18+                 212832
# 2     2021-08-04  Asian  18-34                  72042
# 3     2021-08-04  Asian  35-49                  51508
# 4     2021-08-04  Asian  50-64                  49718
# ...          ...    ...    ...                    ...
# 9931  2020-05-14  White  35-49                   2392
# 9932  2020-05-14  White  50-64                   3062
# 9933  2020-05-14  White  65-79                   2433
# 9934  2020-05-14  White    80+                   1665
# 9935  2020-05-14  White  Total                  11956
#
#       confirmed_cases_percent  deaths_total  deaths_percent  \
# 0                        0.05             4            0.13
# 1                        0.08          7949            0.13
# 2                        0.07            69            0.07
# 3                        0.07           212            0.06
# 4                        0.08          1099            0.09
# ...                       ...           ...             ...
# 9931                     0.18            11            0.08
# 9932                     0.24            96            0.22
# 9933                     0.36           312            0.34
# 9934                     0.44           569            0.42
# 9935                     0.23           991            0.34
#
#       population_percent
# 0                   0.13
# 1                   0.17
# 2                   0.15
# 3                   0.18
# 4                   0.17
# ...                  ...
# 9931                0.33
# 9932                0.43
# 9933                0.54
# 9934                0.57
# 9935                0.37
#
# [9936 rows x 8 columns]

# %%
race_df[race_df.age != '18+']
# Out:
#             date   race    age  confirmed_cases_total  \
# 0     2021-08-04  Asian   0-17                  22067
# 2     2021-08-04  Asian  18-34                  72042
# 3     2021-08-04  Asian  35-49                  51508
# 4     2021-08-04  Asian  50-64                  49718
# 5     2021-08-04  Asian  65-79                  24411
# ...          ...    ...    ...                    ...
# 9931  2020-05-14  White  35-49                   2392
# 9932  2020-05-14  White  50-64                   3062
# 9933  2020-05-14  White  65-79                   2433
# 9934  2020-05-14  White    80+                   1665
# 9935  2020-05-14  White  Total                  11956
#
#       confirmed_cases_percent  deaths_total  deaths_percent  \
# 0                        0.05             4            0.13
# 2                        0.07            69            0.07
# 3                        0.07           212            0.06
# 4                        0.08          1099            0.09
# 5                        0.10          2565            0.12
# ...                       ...           ...             ...
# 9931                     0.18            11            0.08
# 9932                     0.24            96            0.22
# 9933                     0.36           312            0.34
# 9934                     0.44           569            0.42
# 9935                     0.23           991            0.34
#
#       population_percent
# 0                   0.13
# 2                   0.15
# 3                   0.18
# 4                   0.17
# 5                   0.17
# ...                  ...
# 9931                0.33
# 9932                0.43
# 9933                0.54
# 9934                0.57
# 9935                0.37
#
# [8778 rows x 8 columns]

# %%
g = race_df.groupby(['date', 'race', 'age'])['confirmed_cases_total', 'confirmed_cases_percent', 'deaths_total', 'deaths_percent', 'population_percent'].sum().reset_index()
g
# Out:
# <ipython-input-5-b6d144f4f56f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   g = race_df.groupby(['date', 'race', 'age'])['confirmed_cases_total', 'confirmed_cases_percent', 'deaths_total', 'deaths_percent', 'population_percent'].sum().reset_index()
#             date   race    age  confirmed_cases_total  \
# 0     2020-05-14  Asian   0-17                     80
# 1     2020-05-14  Asian  18-34                   1177
# 2     2020-05-14  Asian  35-49                   1498
# 3     2020-05-14  Asian  50-64                   1627
# 4     2020-05-14  Asian  65-79                    873
# ...          ...    ...    ...                    ...
# 8275  2021-08-04  White  35-49                 137783
# 8276  2021-08-04  White  50-64                 144989
# 8277  2021-08-04  White  65-79                  84080
# 8278  2021-08-04  White    80+                  41660
# 8279  2021-08-04  White  Total                 658519
#
#       confirmed_cases_percent  deaths_total  deaths_percent  \
# 0                        0.04             0            0.00
# 1                        0.09             3            0.11
# 2                        0.12            11            0.08
# 3                        0.13            53            0.12
# 4                        0.13           117            0.13
# ...                       ...           ...             ...
# 8275                     0.18           355            0.10
# 8276                     0.24          2211            0.18
# 8277                     0.35          6297            0.29
# 8278                     0.46         10917            0.44
# 8279                     0.21         19883            0.31
#
#       population_percent
# 0                   0.13
# 1                   0.15
# 2                   0.18
# 3                   0.17
# 4                   0.17
# ...                  ...
# 8275                0.33
# 8276                0.43
# 8277                0.54
# 8278                0.57
# 8279                0.37
#
# [8280 rows x 8 columns]

# %%
g.to_csv('races.csv', index=False)
