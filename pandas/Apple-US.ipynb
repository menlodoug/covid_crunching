# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format

# %%
apple_df = pd.read_csv("https://covid19-static.cdn-apple.com/covid19-mobility-data/2102HotfixDev14/v3/en-us/applemobilitytrends-2021-02-24.csv", low_memory=False)
apple_df = apple_df[(apple_df['geo_type'] == 'county') & (apple_df['transportation_type'] == 'driving')]
apple_df["region"]= apple_df["region"].str.replace(" County", "")
apple_df = apple_df.rename({'region' : 'County', 'sub-region' : 'State'}, axis=1)
apple_df = apple_df.drop(['geo_type', 'transportation_type','alternative_name', 'country'], axis=1)
apple_df.head()
# Out:
#              County           State  2020-01-13  2020-01-14  2020-01-15  \
# 2053      Abbeville  South Carolina      100.00      110.87      112.13
# 2054  Acadia Parish       Louisiana      100.00      115.17      120.94
# 2055       Accomack        Virginia      100.00       98.93       99.53
# 2056            Ada           Idaho      100.00       99.89      105.05
# 2058          Adair        Kentucky      100.00       98.00       96.97
#
#       2020-01-16  2020-01-17  2020-01-18  2020-01-19  2020-01-20  ...  \
# 2053      119.64      147.90      118.02       89.97      114.80  ...
# 2054      124.35      153.41      135.03      103.72      115.92  ...
# 2055      107.75      142.90      103.14      109.17      113.61  ...
# 2056      108.43      121.67      111.69       75.31       99.84  ...
# 2058      112.05      125.46      120.67       87.79      111.65  ...
#
#       2021-02-15  2021-02-16  2021-02-17  2021-02-18  2021-02-19  2021-02-20  \
# ...

# %%
apple_df = (apple_df.set_index(['County', 'State'])
   .rename_axis(['Date'], axis=1)
   .stack()
   .reset_index())
apple_df
# Out:
#            County           State        Date      0
# 0       Abbeville  South Carolina  2020-01-13 100.00
# 1       Abbeville  South Carolina  2020-01-14 110.87
# 2       Abbeville  South Carolina  2020-01-15 112.13
# 3       Abbeville  South Carolina  2020-01-16 119.64
# 4       Abbeville  South Carolina  2020-01-17 147.90
# ...           ...             ...         ...    ...
# 850625       Yuma         Arizona  2021-02-20 142.07
# 850626       Yuma         Arizona  2021-02-21 117.49
# 850627       Yuma         Arizona  2021-02-22 124.46
# 850628       Yuma         Arizona  2021-02-23 123.93
# 850629       Yuma         Arizona  2021-02-24 124.49
#
# [850630 rows x 4 columns]

# %%
apple_df = apple_df.rename({0: 'Index'}, axis='columns')
apple_df
# Out:
#            County           State        Date  Index
# 0       Abbeville  South Carolina  2020-01-13 100.00
# 1       Abbeville  South Carolina  2020-01-14 110.87
# 2       Abbeville  South Carolina  2020-01-15 112.13
# 3       Abbeville  South Carolina  2020-01-16 119.64
# 4       Abbeville  South Carolina  2020-01-17 147.90
# ...           ...             ...         ...    ...
# 850625       Yuma         Arizona  2021-02-20 142.07
# 850626       Yuma         Arizona  2021-02-21 117.49
# 850627       Yuma         Arizona  2021-02-22 124.46
# 850628       Yuma         Arizona  2021-02-23 123.93
# 850629       Yuma         Arizona  2021-02-24 124.49
#
# [850630 rows x 4 columns]

# %%
apple_df.to_csv('apple.csv', index=False)
