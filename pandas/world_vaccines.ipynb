# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
country_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')
country_shot.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 31392  Zimbabwe      ZWE  2021-06-30             1332438             777161
# 31393  Zimbabwe      ZWE  2021-07-01             1341960             782698
# 31394  Zimbabwe      ZWE  2021-07-02             1352718             788004
# 31395  Zimbabwe      ZWE  2021-07-03             1359587             791901
# 31396  Zimbabwe      ZWE  2021-07-04             1361210             793077
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 31392                   555277                   16841               23656
# 31393                   559262                    9522               21235
# 31394                   564714                   10758               18686
# 31395                   567686                    6869               15726
# 31396                   568133                    1623               12279
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 31392                               9                              5
# 31393                               9                              5
# 31394                               9                              5
# 31395                               9                              5
# 31396                               9                              5
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 31392                                    4                            1592
# 31393                                    4                            1429
# 31394                                    4                            1257
# 31395                                    4                            1058
# 31396                                    4                             826

# %%
country_vac = country_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
country_vac.rename(columns={'location' : 'country'}, inplace=True)
country_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#              date  total_vaccinations  people_vaccinated  \
# 31392  2021-06-30             1332438             777161
# 31393  2021-07-01             1341960             782698
# 31394  2021-07-02             1352718             788004
# 31395  2021-07-03             1359587             791901
# 31396  2021-07-04             1361210             793077
#
#        people_fully_vaccinated   country
# 31392                   555277  Zimbabwe
# 31393                   559262  Zimbabwe
# 31394                   564714  Zimbabwe
# 31395                   567686  Zimbabwe
# 31396                   568133  Zimbabwe

# %%
country_continent = pd.read_csv('country.csv')
country_continent.head()
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1          Africa    Africa
# 2         Albania    Europe
# 3         Algeria    Africa
# 4  American Samoa   Oceania

# %%
world_df = pd.read_csv('World.csv', encoding='windows-1252')
world_df
# Out:
#      Number           country  Population Yearly Change  Net Change  \
# 0        37       Afghanistan    38928346         2.33%      886592
# 1       140           Albania     2877797        -0.11%       -3120
# 2        33           Algeria    43851044         1.85%      797990
# 3       210    American Samoa       55191        -0.22%        -121
# 4       203           Andorra       77265         0.16%         123
# ..      ...               ...         ...           ...         ...
# 245     nan          Scotland     5463300           NaN         nan
# 246     nan           England    56286961           NaN         nan
# 247     nan             Wales     3152879           NaN         nan
# 248     nan  Northern Ireland     1893667           NaN         nan
# 249     nan          Pitcairn          47           NaN         nan
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 0                 60           652860          -62920           5        18
# 1                105            27400          -14000           2        36
# 2                 18          2381740          -10000           3        29
# 3                276              200             nan         nan       nan
# 4                164              470             nan         nan       nan
# ..               ...              ...             ...         ...       ...
# 245              nan              nan             nan         nan       nan
# 246              nan              nan             nan         nan       nan
# 247              nan              nan             nan         nan       nan
# 248              nan              nan             nan         nan       nan
# 249              nan              nan             nan         nan       nan
#
#     Urban Pop % World Share
# 0           25%       0.50%
# 1           63%       0.04%
# 2           73%       0.56%
# 3           88%       0.00%
# 4           88%       0.00%
# ..          ...         ...
# 245         NaN         NaN
# 246         NaN         NaN
# 247         NaN         NaN
# 248         NaN         NaN
# 249         NaN         NaN
#
# [250 rows x 12 columns]

# %%
country_vaccination = pd.merge(country_vac, country_continent, on='country', how='outer')
country_vaccination
# Out:
#              date  total_vaccinations  people_vaccinated  \
# 0      2021-02-22                   0                  0
# 1      2021-02-23                 nan                nan
# 2      2021-02-24                 nan                nan
# 3      2021-02-25                 nan                nan
# 4      2021-02-26                 nan                nan
# ...           ...                 ...                ...
# 31420         NaN                 nan                nan
# 31421         NaN                 nan                nan
# 31422         NaN                 nan                nan
# 31423         NaN                 nan                nan
# 31424         NaN                 nan                nan
#
#        people_fully_vaccinated                      country      continent
# 0                          nan                  Afghanistan           Asia
# 1                          nan                  Afghanistan           Asia
# 2                          nan                  Afghanistan           Asia
# 3                          nan                  Afghanistan           Asia
# 4                          nan                  Afghanistan           Asia
# ...                        ...                          ...            ...
# 31420                      nan    Saint Pierre and Miquelon  North America
# 31421                      nan  United Republic of Tanzania         Africa
# 31422                      nan                      Tokelau        Oceania
# 31423                      nan          U.S. Virgin Islands  North America
# 31424                      nan               Western Sahara         Africa
#
# [31425 rows x 6 columns]

# %%
df =  pd.merge(country_vaccination, world_df, on='country', how ='outer')
df
# Out:
#              date  total_vaccinations  people_vaccinated  \
# 0      2021-02-22                   0                  0
# 1      2021-02-23                 nan                nan
# 2      2021-02-24                 nan                nan
# 3      2021-02-25                 nan                nan
# 4      2021-02-26                 nan                nan
# ...           ...                 ...                ...
# 31703         NaN                 nan                nan
# 31704         NaN                 nan                nan
# 31705         NaN                 nan                nan
# 31706         NaN                 nan                nan
# 31707         NaN                 nan                nan
#
#        people_fully_vaccinated                      country      continent  \
# 0                          nan                  Afghanistan           Asia
# 1                          nan                  Afghanistan           Asia
# 2                          nan                  Afghanistan           Asia
# 3                          nan                  Afghanistan           Asia
# 4                          nan                  Afghanistan           Asia
# ...                        ...                          ...            ...
# 31703                      nan    Saint Pierre and Miquelon  North America
# 31704                      nan  United Republic of Tanzania         Africa
# 31705                      nan                      Tokelau        Oceania
# 31706                      nan          U.S. Virgin Islands  North America
# 31707                      nan               Western Sahara         Africa
#
#        Number  Population Yearly Change  Net Change  Density (P/Km²)  \
# 0          37    38928346         2.33%      886592               60
# 1          37    38928346         2.33%      886592               60
# 2          37    38928346         2.33%      886592               60
# 3          37    38928346         2.33%      886592               60
# 4          37    38928346         2.33%      886592               60
# ...       ...         ...           ...         ...              ...
# 31703     230        5794        -0.48%         -28               25
# 31704      24    59734218         2.98%     1728755               67
# 31705     234        1357         1.27%          17              136
# 31706     199      104425        -0.15%        -153              298
# 31707     170      597339         2.55%       14876                2
#
#        Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age Urban Pop %  \
# 0               652860          -62920           5        18         25%
# 1               652860          -62920           5        18         25%
# 2               652860          -62920           5        18         25%
# 3               652860          -62920           5        18         25%
# 4               652860          -62920           5        18         25%
# ...                ...             ...         ...       ...         ...
# 31703              230             nan         nan       nan        100%
# 31704           885800          -40076           5        18         37%
# 31705               10             nan         nan       nan          0%
# 31706              350            -451           2        43         96%
# 31707           266000            5582           2        28         87%
#
#       World Share
# 0           0.50%
# 1           0.50%
# 2           0.50%
# 3           0.50%
# 4           0.50%
# ...           ...
# 31703       0.00%
# 31704       0.77%
# 31705       0.00%
# 31706       0.00%
# 31707       0.01%
#
# [31708 rows x 17 columns]

# %%
df.to_csv('country_shot.csv', index=False)
