# %%
import pandas as pd
import numpy as np
import plotly.express as px
pd.options.display.float_format = '{:.0f}'.format

# %%
country_shot = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')
country_shot.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 67353  Zimbabwe      ZWE  2021-12-04             6742193            3866139
# 67354  Zimbabwe      ZWE  2021-12-05             6759589            3875546
# 67355  Zimbabwe      ZWE  2021-12-06             6775471            3883107
# 67356  Zimbabwe      ZWE  2021-12-07             6808392            3897441
# 67357  Zimbabwe      ZWE  2021-12-08             6834846            3908712
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 67353                  2876054             nan                   32098
# 67354                  2884043             nan                   17396
# 67355                  2892364             nan                   15882
# 67356                  2910951             nan                   32921
# 67357                  2926134             nan                   26454
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 67353               25964                              45
# 67354               27271                              45
# 67355               26995                              45
# 67356               28064                              45
# 67357               27772                              45
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 67353                             26                                   19
# 67354                             26                                   19
# 67355                             26                                   19
# 67356                             26                                   19
# 67357                             26                                   19
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 67353                         nan                            1720
# 67354                         nan                            1807
# 67355                         nan                            1789
# 67356                         nan                            1860
# 67357                         nan                            1840
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 67353                    14392                                    0
# 67354                    14951                                    0
# 67355                    14438                                    0
# 67356                    14577                                    0
# 67357                    14116                                    0

# %%
country_vac = country_shot[['date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'location']]
country_vac.rename(columns={'location' : 'country'}, inplace=True)
country_vac.tail()
# Out:
# C:\Users\Doug Smith\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#              date  total_vaccinations  people_vaccinated  \
# 67353  2021-12-04             6742193            3866139
# 67354  2021-12-05             6759589            3875546
# 67355  2021-12-06             6775471            3883107
# 67356  2021-12-07             6808392            3897441
# 67357  2021-12-08             6834846            3908712
#
#        people_fully_vaccinated   country
# 67353                  2876054  Zimbabwe
# 67354                  2884043  Zimbabwe
# 67355                  2892364  Zimbabwe
# 67356                  2910951  Zimbabwe
# 67357                  2926134  Zimbabwe

# %%
country_continent = pd.read_csv('country.csv')
country_continent.head()
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1          Africa    Africa
# 2         Albania    Europe
# 3         Algeria    Africa
# 4  American Samoa   Oceania

# %%
world_df = pd.read_csv('World.csv', encoding='windows-1252')
world_df
# Out:
#      Number           country  Population Yearly Change  Net Change  \
# 0        37       Afghanistan    38928346         2.33%      886592
# 1       140           Albania     2877797        -0.11%       -3120
# 2        33           Algeria    43851044         1.85%      797990
# 3       210    American Samoa       55191        -0.22%        -121
# 4       203           Andorra       77265         0.16%         123
# ..      ...               ...         ...           ...         ...
# 245     nan          Scotland     5463300           NaN         nan
# 246     nan           England    56286961           NaN         nan
# 247     nan             Wales     3152879           NaN         nan
# 248     nan  Northern Ireland     1893667           NaN         nan
# 249     nan          Pitcairn          47           NaN         nan
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 0                 60           652860          -62920           5        18
# 1                105            27400          -14000           2        36
# 2                 18          2381740          -10000           3        29
# 3                276              200             nan         nan       nan
# 4                164              470             nan         nan       nan
# ..               ...              ...             ...         ...       ...
# 245              nan              nan             nan         nan       nan
# 246              nan              nan             nan         nan       nan
# 247              nan              nan             nan         nan       nan
# 248              nan              nan             nan         nan       nan
# 249              nan              nan             nan         nan       nan
#
#     Urban Pop % World Share
# 0           25%       0.50%
# 1           63%       0.04%
# 2           73%       0.56%
# 3           88%       0.00%
# 4           88%       0.00%
# ..          ...         ...
# 245         NaN         NaN
# 246         NaN         NaN
# 247         NaN         NaN
# 248         NaN         NaN
# 249         NaN         NaN
#
# [250 rows x 12 columns]

# %%
country_vaccination = pd.merge(country_vac, country_continent, on='country', how='outer')
country_vaccination
# Out:
#              date  total_vaccinations  people_vaccinated  \
# 0      2021-02-22                   0                  0
# 1      2021-02-23                 nan                nan
# 2      2021-02-24                 nan                nan
# 3      2021-02-25                 nan                nan
# 4      2021-02-26                 nan                nan
# ...           ...                 ...                ...
# 67376         NaN                 nan                nan
# 67377         NaN                 nan                nan
# 67378         NaN                 nan                nan
# 67379         NaN                 nan                nan
# 67380         NaN                 nan                nan
#
#        people_fully_vaccinated                      country      continent
# 0                          nan                  Afghanistan           Asia
# 1                          nan                  Afghanistan           Asia
# 2                          nan                  Afghanistan           Asia
# 3                          nan                  Afghanistan           Asia
# 4                          nan                  Afghanistan           Asia
# ...                        ...                          ...            ...
# 67376                      nan                 Saint Martin  North America
# 67377                      nan    Saint Pierre and Miquelon  North America
# 67378                      nan  United Republic of Tanzania         Africa
# 67379                      nan          U.S. Virgin Islands  North America
# 67380                      nan               Western Sahara         Africa
#
# [67381 rows x 6 columns]

# %%
df =  pd.merge(country_vaccination, world_df, on='country', how ='outer')
df
# Out:
#              date  total_vaccinations  people_vaccinated  \
# 0      2021-02-22                   0                  0
# 1      2021-02-23                 nan                nan
# 2      2021-02-24                 nan                nan
# 3      2021-02-25                 nan                nan
# 4      2021-02-26                 nan                nan
# ...           ...                 ...                ...
# 67968         NaN                 nan                nan
# 67969         NaN                 nan                nan
# 67970         NaN                 nan                nan
# 67971         NaN                 nan                nan
# 67972         NaN                 nan                nan
#
#        people_fully_vaccinated                      country      continent  \
# 0                          nan                  Afghanistan           Asia
# 1                          nan                  Afghanistan           Asia
# 2                          nan                  Afghanistan           Asia
# 3                          nan                  Afghanistan           Asia
# 4                          nan                  Afghanistan           Asia
# ...                        ...                          ...            ...
# 67968                      nan                 Saint Martin  North America
# 67969                      nan    Saint Pierre and Miquelon  North America
# 67970                      nan  United Republic of Tanzania         Africa
# 67971                      nan          U.S. Virgin Islands  North America
# 67972                      nan               Western Sahara         Africa
#
#        Number  Population Yearly Change  Net Change  Density (P/Km²)  \
# 0          37    38928346         2.33%      886592               60
# 1          37    38928346         2.33%      886592               60
# 2          37    38928346         2.33%      886592               60
# 3          37    38928346         2.33%      886592               60
# 4          37    38928346         2.33%      886592               60
# ...       ...         ...           ...         ...              ...
# 67968     216       38666         1.75%         664              730
# 67969     230        5794        -0.48%         -28               25
# 67970      24    59734218         2.98%     1728755               67
# 67971     199      104425        -0.15%        -153              298
# 67972     170      597339         2.55%       14876                2
#
#        Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age Urban Pop %  \
# 0               652860          -62920           5        18         25%
# 1               652860          -62920           5        18         25%
# 2               652860          -62920           5        18         25%
# 3               652860          -62920           5        18         25%
# 4               652860          -62920           5        18         25%
# ...                ...             ...         ...       ...         ...
# 67968               53             nan         nan       nan          0%
# 67969              230             nan         nan       nan        100%
# 67970           885800          -40076           5        18         37%
# 67971              350            -451           2        43         96%
# 67972           266000            5582           2        28         87%
#
#       World Share
# 0           0.50%
# 1           0.50%
# 2           0.50%
# 3           0.50%
# 4           0.50%
# ...           ...
# 67968       0.00%
# 67969       0.00%
# 67970       0.77%
# 67971       0.00%
# 67972       0.01%
#
# [67973 rows x 17 columns]

# %%
df.to_csv('country_shot.csv', index=False)

# %%
uk_shot = df.loc[(df['country'] == 'Scotland') | (df['country'] == 'England') | (df['country'] == 'Wales') | (df['country'] == 'Northern Ireland')]
uk_shot.to_csv('uk_shot.csv', index=False)
